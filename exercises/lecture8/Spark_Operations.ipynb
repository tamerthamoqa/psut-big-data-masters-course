# %% [markdown]
# ##Apache Spark with Google Colab
#
#
# Setting up  Spark 2.4.7 with all dependencies on google colab.
#
# * Installing Java in the Google Colaboratory
# * Setting up Spark 2.4.7  in the Google Colaboratory
# * A test example

# %% [markdown]
# # Setting up Spark 2.4.7 the Google Colaboratory
#
# This notebook comprises the instructions to run pyspark on google Colab.
#
# We will install the following OS tools
#
# * Java 8
# * spark-2.4.7
# * Hadoop2.7
# * [Findspark](https://github.com/minrk/findspark)
#
#
# > Make sure the spark-version you are downloading is availbale on target link

# %%
import time

Start=time.time()
# Download and install tools 

# Install Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download and Install Spark
# !wget  -q http://apache.osuosl.org/spark/spark-2.4.7/spark-2.4.7-bin-hadoop2.7.tgz
# !tar xf spark-2.4.7-bin-hadoop2.7.tgz

# Install findspark
# !pip install -q findspark

print(f"\nIt took {(time.time()-Start)} seconds to install all dependencies for spark to run on Google Colab. \n")
# Out:
# It took 30.047858476638794 seconds to install all dependencies for spark to run on Google Colab.

# %%
# Set environment variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.7-bin-hadoop2.7"

# %% [markdown]
# ## Spark Installation test
# Lets test the installation of spark in our google colab environment.

# %%
import findspark
import numpy as np
findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").getOrCreate()
# Test the spark 
NameList = ['Ahmad', 'Salem', 'Noor', 'Heba']

NumberOfSamples=int(1000)

df = spark.createDataFrame([{"Column1": np.random.randint(1,100), 
                             "Column2":np.random.randint(24,35), 
                             "Column3":np.random.random(),
                             "Name":str(np.random.choice(NameList,p=[.5,.2,.1,.2])),
                             }
                              for i in range(NumberOfSamples)])

df.show(3, False)

#spark.stop()
# Out:
# /content/spark-2.4.7-bin-hadoop2.7/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"
# +-------+-------+------------------+-----+
# |Column1|Column2|Column3           |Name |
# +-------+-------+------------------+-----+
# |59     |31     |0.3736162801327363|Heba |
# |75     |28     |0.6738893595145822|Ahmad|
# |60     |32     |0.8902618906934348|Ahmad|
# +-------+-------+------------------+-----+
# only showing top 3 rows

# %% [markdown]
# ##Actions

# %% [markdown]
# ####PrintSchem Prints out the schema in the tree format.

# %%
df.printSchema()
# Out:
# root
#  |-- Column1: long (nullable = true)
#  |-- Column2: long (nullable = true)
#  |-- Column3: double (nullable = true)
#  |-- Name: string (nullable = true)

# %% [markdown]
# ####collect: Returns all the records as a list of rows..

# %%
df.collect() # Very heavy and will consume the RAM
# Out:
# [Row(Column1=59, Column2=31, Column3=0.3736162801327363, Name='Heba'),
#  Row(Column1=75, Column2=28, Column3=0.6738893595145822, Name='Ahmad'),
#  Row(Column1=60, Column2=32, Column3=0.8902618906934348, Name='Ahmad'),
#  Row(Column1=59, Column2=27, Column3=0.46576177438844135, Name='Salem'),
#  Row(Column1=72, Column2=33, Column3=0.366988985365314, Name='Salem'),
#  Row(Column1=30, Column2=25, Column3=0.8782213069230462, Name='Heba'),
#  Row(Column1=31, Column2=31, Column3=0.569279252419162, Name='Heba'),
#  Row(Column1=80, Column2=27, Column3=0.6620355108525771, Name='Ahmad'),
#  Row(Column1=66, Column2=33, Column3=0.10639853662690446, Name='Ahmad'),
#  Row(Column1=32, Column2=33, Column3=0.4802386999319148, Name='Salem'),
#  Row(Column1=1, Column2=30, Column3=0.2152023280130233, Name='Ahmad'),
#  Row(Column1=5, Column2=28, Column3=0.06874033954386938, Name='Ahmad'),
#  Row(Column1=27, Column2=28, Column3=0.6320790053248823, Name='Noor'),
#  Row(Column1=40, Column2=24, Column3=0.6282966381785714, Name='Salem'),
#  Row(Column1=44, Column2=24, Column3=0.22915813108987837, Name='Ahmad'),
#  Row(Column1=5, Column2=32, Column3=0.8830634655906385, Name='Ahmad'),
#  Row(Column1=21, Column2=25, Column3=0.6810848858026288, Name='Ahmad'),
#  Row(Column1=87, Column2=28, Column3=0.6573485056238851, Name='Ahmad'),
#  Row(Column1=41, Column2=31, Column3=0.5842473732505203, Name='Ahmad'),
#  Row(Column1=61, Column2=27, Column3=0.43966680805990477, Name='Noor'),
#  Row(Column1=96, Column2=25, Column3=0.3418952522260448, Name='Heba'),
#  Row(Column1=15, Column2=30, Column3=0.6020950606252093, Name='Ahmad'),
#  Row(Column1=37, Column2=27, Column3=0.08254269113224244, Name='Ahmad'),
#  Row(Column1=57, Column2=33, Column3=0.5005337289184657, Name='Ahmad'),
#  Row(Column1=4, Column2=30, Column3=0.7023205717697689, Name='Salem'),
#  Row(Column1=1, Column2=34, Column3=0.5731735219752424, Name='Ahmad'),
#  Row(Column1=87, Column2=30, Column3=0.9989253319612467, Name='Ahmad'),
#  Row(Column1=78, Column2=32, Column3=0.5242991772084299, Name='Noor'),
#  Row(Column1=40, Column2=26, Column3=0.8250194575162141, Name='Ahmad'),
#  Row(Column1=33, Column2=29, Column3=0.1461343986071737, Name='Ahmad'),
#  Row(Column1=57, Column2=25, Column3=0.030416655656447023, Name='Ahmad'),
#  Row(Column1=89, Column2=31, Column3=0.4094561796663593, Name='Noor'),
#  Row(Column1=25, Column2=31, Column3=0.28439124023153495, Name='Salem'),
#  Row(Column1=41, Column2=34, Column3=0.4772237462631387, Name='Noor'),
#  Row(Column1=19, Column2=31, Column3=0.8369902565490176, Name='Ahmad'),
#  Row(Column1=24, Column2=31, Column3=0.26136397324708593, Name='Ahmad'),
#  Row(Column1=81, Column2=31, Column3=0.42887217994410465, Name='Ahmad'),
#  Row(Column1=73, Column2=29, Column3=0.8708872849645946, Name='Ahmad'),
#  Row(Column1=21, Column2=24, Column3=0.10892022364544918, Name='Salem'),
#  Row(Column1=85, Column2=28, Column3=0.6370521352021283, Name='Ahmad'),
#  Row(Column1=8, Column2=31, Column3=0.08639647141534423, Name='Ahmad'),
#  Row(Column1=34, Column2=27, Column3=0.9490694468533586, Name='Heba'),
#  Row(Column1=2, Column2=27, Column3=0.011823293867955997, Name='Ahmad'),
#  Row(Column1=77, Column2=28, Column3=0.8239452093062817, Name='Heba'),
#  Row(Column1=87, Column2=27, Column3=0.255172259417178, Name='Salem'),
#  Row(Column1=68, Column2=25, Column3=0.652358127946006, Name='Ahmad'),
#  Row(Column1=58, Column2=31, Column3=0.3916545201753857, Name='Ahmad'),
#  Row(Column1=86, Column2=27, Column3=0.2520047229348613, Name='Ahmad'),
#  Row(Column1=26, Column2=32, Column3=0.5136544720898832, Name='Heba'),
#  Row(Column1=17, Column2=26, Column3=0.5254259752363017, Name='Salem'),
#  Row(Column1=98, Column2=29, Column3=0.7374076883884042, Name='Salem'),
#  Row(Column1=61, Column2=26, Column3=0.8836360441578545, Name='Ahmad'),
#  Row(Column1=76, Column2=33, Column3=0.09475548570055004, Name='Noor'),
#  Row(Column1=11, Column2=26, Column3=0.10196372452968516, Name='Ahmad'),
#  Row(Column1=43, Column2=29, Column3=0.9781319718478739, Name='Ahmad'),
#  Row(Column1=40, Column2=27, Column3=0.1403169875324779, Name='Ahmad'),
#  Row(Column1=24, Column2=30, Column3=0.4292202901641471, Name='Ahmad'),
#  Row(Column1=60, Column2=33, Column3=0.17989295063845112, Name='Heba'),
#  Row(Column1=8, Column2=33, Column3=0.7015911378888162, Name='Noor'),
#  Row(Column1=19, Column2=25, Column3=0.8374644360935153, Name='Ahmad'),
#  Row(Column1=44, Column2=31, Column3=0.5224910809392337, Name='Ahmad'),
#  Row(Column1=38, Column2=26, Column3=0.574596868022887, Name='Ahmad'),
#  Row(Column1=86, Column2=27, Column3=0.27546718493473166, Name='Ahmad'),
#  Row(Column1=31, Column2=32, Column3=0.6118762722820451, Name='Noor'),
#  Row(Column1=89, Column2=26, Column3=0.08946871636163745, Name='Heba'),
#  Row(Column1=73, Column2=24, Column3=0.40530897909203134, Name='Heba'),
#  Row(Column1=89, Column2=29, Column3=0.2310208765828119, Name='Ahmad'),
#  Row(Column1=7, Column2=25, Column3=0.1233614753794755, Name='Salem'),
#  Row(Column1=32, Column2=32, Column3=0.9507313625829911, Name='Ahmad'),
#  Row(Column1=47, Column2=26, Column3=0.5079447649567892, Name='Heba'),
#  Row(Column1=80, Column2=33, Column3=0.537624783214555, Name='Heba'),
#  Row(Column1=59, Column2=27, Column3=0.5618511900759521, Name='Salem'),
#  Row(Column1=52, Column2=25, Column3=0.7072769161727083, Name='Noor'),
#  Row(Column1=80, Column2=30, Column3=0.7857586065476604, Name='Ahmad'),
#  Row(Column1=28, Column2=24, Column3=0.3824435151954, Name='Ahmad'),
#  Row(Column1=14, Column2=32, Column3=0.6652175392216563, Name='Heba'),
#  Row(Column1=13, Column2=31, Column3=0.9864582227235734, Name='Heba'),
#  Row(Column1=40, Column2=34, Column3=0.42452729500109543, Name='Noor'),
#  Row(Column1=38, Column2=33, Column3=0.07678600836643146, Name='Ahmad'),
#  Row(Column1=13, Column2=32, Column3=0.8673714117515897, Name='Heba'),
#  Row(Column1=63, Column2=29, Column3=0.06268018796173969, Name='Ahmad'),
#  Row(Column1=80, Column2=29, Column3=0.5430771045325545, Name='Ahmad'),
#  Row(Column1=20, Column2=33, Column3=0.1002426322466996, Name='Salem'),
#  Row(Column1=88, Column2=33, Column3=0.28990727049490983, Name='Ahmad'),
#  Row(Column1=88, Column2=34, Column3=0.3113383091078873, Name='Heba'),
#  Row(Column1=10, Column2=30, Column3=0.4645711128456278, Name='Heba'),
#  Row(Column1=36, Column2=34, Column3=0.5178383314631458, Name='Heba'),
#  Row(Column1=14, Column2=34, Column3=0.3487756734352816, Name='Noor'),
#  Row(Column1=19, Column2=32, Column3=0.5838059952613988, Name='Heba'),
#  Row(Column1=18, Column2=25, Column3=0.12004324868803706, Name='Salem'),
#  Row(Column1=8, Column2=26, Column3=0.7663302019598633, Name='Ahmad'),
#  Row(Column1=40, Column2=26, Column3=0.6792870536891297, Name='Ahmad'),
#  Row(Column1=22, Column2=29, Column3=0.8710928269161516, Name='Ahmad'),
#  Row(Column1=10, Column2=31, Column3=0.8204664832800898, Name='Ahmad'),
#  Row(Column1=78, Column2=25, Column3=0.429655861329715, Name='Ahmad'),
#  Row(Column1=27, Column2=32, Column3=0.30183300302619287, Name='Ahmad'),
#  Row(Column1=45, Column2=26, Column3=0.9773704006912354, Name='Heba'),
#  Row(Column1=8, Column2=32, Column3=0.5883775664896878, Name='Heba'),
#  Row(Column1=44, Column2=34, Column3=0.8918811804987682, Name='Ahmad'),
#  Row(Column1=48, Column2=30, Column3=0.20249475658912985, Name='Heba'),
#  Row(Column1=57, Column2=26, Column3=0.5537672477105158, Name='Ahmad'),
#  Row(Column1=89, Column2=25, Column3=0.04968832161698811, Name='Ahmad'),
#  Row(Column1=98, Column2=24, Column3=0.7983478237297943, Name='Ahmad'),
#  Row(Column1=85, Column2=34, Column3=0.9846997821339234, Name='Salem'),
#  Row(Column1=17, Column2=31, Column3=0.613860606341719, Name='Noor'),
#  Row(Column1=63, Column2=25, Column3=0.675607696023433, Name='Ahmad'),
#  Row(Column1=21, Column2=26, Column3=0.2754907803310124, Name='Heba'),
#  Row(Column1=38, Column2=28, Column3=0.5906745559103355, Name='Ahmad'),
#  Row(Column1=1, Column2=33, Column3=0.022001741550304654, Name='Salem'),
#  Row(Column1=27, Column2=24, Column3=0.32221453289793855, Name='Salem'),
#  Row(Column1=18, Column2=31, Column3=0.3836531913798633, Name='Ahmad'),
#  Row(Column1=24, Column2=34, Column3=0.11932291610936019, Name='Ahmad'),
#  Row(Column1=51, Column2=33, Column3=0.783068090467705, Name='Salem'),
#  Row(Column1=12, Column2=25, Column3=0.6588858331470696, Name='Ahmad'),
#  Row(Column1=25, Column2=29, Column3=0.12748297650542817, Name='Noor'),
#  Row(Column1=3, Column2=28, Column3=0.0856299748738184, Name='Heba'),
#  Row(Column1=44, Column2=25, Column3=0.22844285581132573, Name='Noor'),
#  Row(Column1=38, Column2=33, Column3=0.04761497800222203, Name='Ahmad'),
#  Row(Column1=63, Column2=27, Column3=0.5064969937838866, Name='Ahmad'),
#  Row(Column1=60, Column2=32, Column3=0.9291524498160921, Name='Salem'),
#  Row(Column1=82, Column2=28, Column3=0.5203708202210173, Name='Ahmad'),
#  Row(Column1=65, Column2=27, Column3=0.9557255843195434, Name='Heba'),
#  Row(Column1=46, Column2=29, Column3=0.3654019801969165, Name='Ahmad'),
#  Row(Column1=90, Column2=26, Column3=0.4750260762987383, Name='Ahmad'),
#  Row(Column1=89, Column2=33, Column3=0.18744811448410947, Name='Heba'),
#  Row(Column1=85, Column2=30, Column3=0.6954807857553086, Name='Salem'),
#  Row(Column1=54, Column2=27, Column3=0.0968048819885049, Name='Ahmad'),
#  Row(Column1=41, Column2=26, Column3=0.8706812778478796, Name='Heba'),
#  Row(Column1=78, Column2=24, Column3=0.6865908136957265, Name='Ahmad'),
#  Row(Column1=71, Column2=24, Column3=0.7389909281589402, Name='Ahmad'),
#  Row(Column1=66, Column2=32, Column3=0.9536198776269752, Name='Heba'),
#  Row(Column1=13, Column2=32, Column3=0.5331557188871213, Name='Salem'),
#  Row(Column1=6, Column2=34, Column3=0.1295616880104069, Name='Heba'),
#  Row(Column1=42, Column2=30, Column3=0.676069168834928, Name='Ahmad'),
#  Row(Column1=31, Column2=29, Column3=0.6124174675464549, Name='Ahmad'),
#  Row(Column1=86, Column2=34, Column3=0.5498419154861339, Name='Ahmad'),
#  Row(Column1=12, Column2=25, Column3=0.396729775220076, Name='Heba'),
#  Row(Column1=69, Column2=25, Column3=0.0842123167046468, Name='Ahmad'),
#  Row(Column1=3, Column2=25, Column3=0.61272320198356, Name='Ahmad'),
#  Row(Column1=29, Column2=25, Column3=0.23236448752340377, Name='Ahmad'),
#  Row(Column1=40, Column2=32, Column3=0.6061738681574034, Name='Ahmad'),
#  Row(Column1=28, Column2=31, Column3=0.9601470574728143, Name='Ahmad'),
#  Row(Column1=62, Column2=29, Column3=0.3023823217965347, Name='Ahmad'),
#  Row(Column1=16, Column2=31, Column3=0.2962172438808013, Name='Salem'),
#  Row(Column1=64, Column2=27, Column3=0.8480082350147291, Name='Heba'),
#  Row(Column1=71, Column2=34, Column3=0.7181539268603493, Name='Ahmad'),
#  Row(Column1=38, Column2=26, Column3=0.9047736549365122, Name='Heba'),
#  Row(Column1=11, Column2=25, Column3=0.5980489818074121, Name='Noor'),
#  Row(Column1=93, Column2=27, Column3=0.772100880490557, Name='Ahmad'),
#  Row(Column1=50, Column2=34, Column3=0.3879337436529341, Name='Ahmad'),
#  Row(Column1=89, Column2=32, Column3=0.996278297083931, Name='Heba'),
#  Row(Column1=30, Column2=34, Column3=0.9388835739635693, Name='Ahmad'),
#  Row(Column1=36, Column2=34, Column3=0.7187625229690292, Name='Ahmad'),
#  Row(Column1=19, Column2=25, Column3=0.23282843081815052, Name='Ahmad'),
#  Row(Column1=44, Column2=34, Column3=0.4339113147492001, Name='Ahmad'),
#  Row(Column1=78, Column2=30, Column3=0.14472465995893258, Name='Heba'),
#  Row(Column1=61, Column2=29, Column3=0.782228333664908, Name='Ahmad'),
#  Row(Column1=25, Column2=24, Column3=0.13410973021174522, Name='Ahmad'),
#  Row(Column1=4, Column2=27, Column3=0.3828236660924147, Name='Salem'),
#  Row(Column1=88, Column2=27, Column3=0.2714939307861778, Name='Ahmad'),
#  Row(Column1=79, Column2=30, Column3=0.9445819969725485, Name='Ahmad'),
#  Row(Column1=2, Column2=24, Column3=0.05337981938246328, Name='Ahmad'),
#  Row(Column1=71, Column2=29, Column3=0.762471983551484, Name='Heba'),
#  Row(Column1=59, Column2=29, Column3=0.3444382776938135, Name='Heba'),
#  Row(Column1=89, Column2=24, Column3=0.9332652584719046, Name='Ahmad'),
#  Row(Column1=54, Column2=27, Column3=0.8037216200471282, Name='Salem'),
#  Row(Column1=82, Column2=28, Column3=0.2362918911076196, Name='Ahmad'),
#  Row(Column1=32, Column2=24, Column3=0.747122886174015, Name='Ahmad'),
#  Row(Column1=32, Column2=34, Column3=0.7434651585924666, Name='Ahmad'),
#  Row(Column1=73, Column2=25, Column3=0.9597883194374438, Name='Noor'),
#  Row(Column1=95, Column2=26, Column3=0.791514741063026, Name='Ahmad'),
#  Row(Column1=13, Column2=29, Column3=0.6991163355699527, Name='Ahmad'),
#  Row(Column1=54, Column2=33, Column3=0.1933569185695272, Name='Ahmad'),
#  Row(Column1=65, Column2=30, Column3=0.11653665441027194, Name='Ahmad'),
#  Row(Column1=96, Column2=28, Column3=0.4953241814907192, Name='Heba'),
#  Row(Column1=83, Column2=33, Column3=0.8749984458849518, Name='Ahmad'),
#  Row(Column1=33, Column2=32, Column3=0.15915437077896466, Name='Ahmad'),
#  Row(Column1=65, Column2=27, Column3=0.5960712349817383, Name='Heba'),
#  Row(Column1=51, Column2=33, Column3=0.1651302641600365, Name='Ahmad'),
#  Row(Column1=71, Column2=28, Column3=0.0887647533973509, Name='Ahmad'),
#  Row(Column1=24, Column2=26, Column3=0.3586042524466545, Name='Ahmad'),
#  Row(Column1=71, Column2=33, Column3=0.6952675927155239, Name='Ahmad'),
#  Row(Column1=40, Column2=31, Column3=0.9179324587920636, Name='Ahmad'),
#  Row(Column1=56, Column2=30, Column3=0.5709242128730522, Name='Noor'),
#  Row(Column1=14, Column2=33, Column3=0.3431162161460023, Name='Ahmad'),
#  Row(Column1=1, Column2=26, Column3=0.3299293408454752, Name='Ahmad'),
#  Row(Column1=13, Column2=31, Column3=0.9079402610678355, Name='Heba'),
#  Row(Column1=74, Column2=24, Column3=0.36636851653267066, Name='Noor'),
#  Row(Column1=62, Column2=27, Column3=0.48459686078423536, Name='Ahmad'),
#  Row(Column1=2, Column2=34, Column3=0.13979169608096853, Name='Salem'),
#  Row(Column1=57, Column2=29, Column3=0.14722236784775233, Name='Noor'),
#  Row(Column1=52, Column2=34, Column3=0.8722046854668287, Name='Ahmad'),
#  Row(Column1=77, Column2=26, Column3=0.8646912898124348, Name='Noor'),
#  Row(Column1=56, Column2=29, Column3=0.4608363564395912, Name='Ahmad'),
#  Row(Column1=7, Column2=34, Column3=0.9351457612056915, Name='Ahmad'),
#  Row(Column1=44, Column2=29, Column3=0.28793528188282835, Name='Ahmad'),
#  Row(Column1=45, Column2=30, Column3=0.9822035242345913, Name='Ahmad'),
#  Row(Column1=56, Column2=33, Column3=0.7387431527428272, Name='Ahmad'),
#  Row(Column1=66, Column2=28, Column3=0.3002821188835141, Name='Ahmad'),
#  Row(Column1=62, Column2=31, Column3=0.4889962082540108, Name='Ahmad'),
#  Row(Column1=31, Column2=32, Column3=0.47410144550872146, Name='Salem'),
#  Row(Column1=83, Column2=30, Column3=0.7663396308658565, Name='Salem'),
#  Row(Column1=59, Column2=33, Column3=0.6871642010256429, Name='Ahmad'),
#  Row(Column1=53, Column2=27, Column3=0.0025354685321706816, Name='Ahmad'),
#  Row(Column1=99, Column2=29, Column3=0.9377296636827545, Name='Ahmad'),
#  Row(Column1=22, Column2=33, Column3=0.24376796912763432, Name='Ahmad'),
#  Row(Column1=57, Column2=24, Column3=0.5097456673309055, Name='Salem'),
#  Row(Column1=11, Column2=24, Column3=0.34699530856424965, Name='Noor'),
#  Row(Column1=40, Column2=31, Column3=0.702239836171612, Name='Ahmad'),
#  Row(Column1=85, Column2=28, Column3=0.7004951602814836, Name='Ahmad'),
#  Row(Column1=18, Column2=26, Column3=0.9880017076553625, Name='Ahmad'),
#  Row(Column1=2, Column2=29, Column3=0.6987337429490496, Name='Salem'),
#  Row(Column1=59, Column2=25, Column3=0.622153330908481, Name='Ahmad'),
#  Row(Column1=12, Column2=25, Column3=0.016176351948453127, Name='Heba'),
#  Row(Column1=34, Column2=34, Column3=0.9197751955388315, Name='Ahmad'),
#  Row(Column1=71, Column2=29, Column3=0.6519726215628683, Name='Salem'),
#  Row(Column1=29, Column2=28, Column3=0.9597611416956229, Name='Ahmad'),
#  Row(Column1=24, Column2=27, Column3=0.13368303012162253, Name='Heba'),
#  Row(Column1=57, Column2=31, Column3=0.9542241568248377, Name='Ahmad'),
#  Row(Column1=16, Column2=31, Column3=0.55169312307317, Name='Ahmad'),
#  Row(Column1=4, Column2=31, Column3=0.09631797682421506, Name='Ahmad'),
#  Row(Column1=19, Column2=34, Column3=0.5486642036835973, Name='Salem'),
#  Row(Column1=27, Column2=33, Column3=0.37798035931316465, Name='Noor'),
#  Row(Column1=78, Column2=27, Column3=0.9101048787163023, Name='Ahmad'),
#  Row(Column1=93, Column2=25, Column3=0.28816889348090224, Name='Noor'),
#  Row(Column1=2, Column2=28, Column3=0.7173069152661877, Name='Salem'),
#  Row(Column1=21, Column2=32, Column3=0.21858948531339728, Name='Ahmad'),
#  Row(Column1=24, Column2=34, Column3=0.6766749502142673, Name='Ahmad'),
#  Row(Column1=34, Column2=24, Column3=0.7855007113500942, Name='Ahmad'),
#  Row(Column1=63, Column2=33, Column3=0.7591909379493103, Name='Ahmad'),
#  Row(Column1=83, Column2=29, Column3=0.37716415489991373, Name='Salem'),
#  Row(Column1=54, Column2=25, Column3=0.6604912642941805, Name='Heba'),
#  Row(Column1=87, Column2=33, Column3=0.1656412569559328, Name='Ahmad'),
#  Row(Column1=20, Column2=33, Column3=0.7182927080637413, Name='Ahmad'),
#  Row(Column1=42, Column2=28, Column3=0.16559971460091638, Name='Ahmad'),
#  Row(Column1=14, Column2=34, Column3=0.8230257869851982, Name='Ahmad'),
#  Row(Column1=45, Column2=27, Column3=0.9916440648213062, Name='Ahmad'),
#  Row(Column1=43, Column2=25, Column3=0.7157127518095234, Name='Salem'),
#  Row(Column1=69, Column2=31, Column3=0.47478719874637587, Name='Heba'),
#  Row(Column1=34, Column2=31, Column3=0.10516445076986891, Name='Heba'),
#  Row(Column1=37, Column2=25, Column3=0.1373069742494547, Name='Ahmad'),
#  Row(Column1=18, Column2=28, Column3=0.8623701874697892, Name='Ahmad'),
#  Row(Column1=7, Column2=27, Column3=0.8104997416084275, Name='Ahmad'),
#  Row(Column1=86, Column2=33, Column3=0.3454840368598041, Name='Salem'),
#  Row(Column1=52, Column2=24, Column3=0.7958291065009987, Name='Heba'),
#  Row(Column1=90, Column2=32, Column3=0.8164820050965609, Name='Ahmad'),
#  Row(Column1=3, Column2=28, Column3=0.31829070223314393, Name='Salem'),
#  Row(Column1=79, Column2=24, Column3=0.09759217616119609, Name='Ahmad'),
#  Row(Column1=7, Column2=25, Column3=0.7635592484939744, Name='Noor'),
#  Row(Column1=3, Column2=33, Column3=0.9496894718829701, Name='Salem'),
#  Row(Column1=99, Column2=28, Column3=0.6448824206750591, Name='Noor'),
#  Row(Column1=66, Column2=24, Column3=0.1664694732310822, Name='Ahmad'),
#  Row(Column1=31, Column2=31, Column3=0.40908483239186944, Name='Heba'),
#  Row(Column1=91, Column2=24, Column3=0.650135710514242, Name='Salem'),
#  Row(Column1=30, Column2=29, Column3=0.42614639532088594, Name='Ahmad'),
#  Row(Column1=14, Column2=25, Column3=0.5975023322747296, Name='Heba'),
#  Row(Column1=99, Column2=29, Column3=0.5058868304302355, Name='Salem'),
#  Row(Column1=34, Column2=31, Column3=0.09667800056194775, Name='Salem'),
#  Row(Column1=17, Column2=26, Column3=0.3659418938635898, Name='Heba'),
#  Row(Column1=64, Column2=26, Column3=0.7594265434185935, Name='Salem'),
#  Row(Column1=74, Column2=31, Column3=0.39982903031931916, Name='Ahmad'),
#  Row(Column1=52, Column2=25, Column3=0.5898977124827572, Name='Salem'),
#  Row(Column1=63, Column2=34, Column3=0.6962260690883244, Name='Heba'),
#  Row(Column1=22, Column2=30, Column3=0.7806944907718962, Name='Salem'),
#  Row(Column1=19, Column2=26, Column3=0.13455663517674887, Name='Heba'),
#  Row(Column1=66, Column2=26, Column3=0.8029587383935518, Name='Ahmad'),
#  Row(Column1=95, Column2=27, Column3=0.34339979388830744, Name='Salem'),
#  Row(Column1=26, Column2=27, Column3=0.18722295812581136, Name='Heba'),
#  Row(Column1=98, Column2=32, Column3=0.2692778281925905, Name='Heba'),
#  Row(Column1=11, Column2=26, Column3=0.755200874511551, Name='Salem'),
#  Row(Column1=63, Column2=25, Column3=0.47433202803592434, Name='Ahmad'),
#  Row(Column1=96, Column2=34, Column3=0.11721170007028048, Name='Ahmad'),
#  Row(Column1=3, Column2=27, Column3=0.31869735481671024, Name='Ahmad'),
#  Row(Column1=75, Column2=25, Column3=0.01935855391312069, Name='Ahmad'),
#  Row(Column1=98, Column2=33, Column3=0.43135926400184355, Name='Salem'),
#  Row(Column1=51, Column2=33, Column3=0.890593922447823, Name='Salem'),
#  Row(Column1=40, Column2=29, Column3=0.9132834813839801, Name='Ahmad'),
#  Row(Column1=24, Column2=29, Column3=0.1324377725000121, Name='Ahmad'),
#  Row(Column1=53, Column2=26, Column3=0.5177745143178395, Name='Heba'),
#  Row(Column1=32, Column2=31, Column3=0.928139128161723, Name='Ahmad'),
#  Row(Column1=48, Column2=25, Column3=0.8926071639180493, Name='Ahmad'),
#  Row(Column1=32, Column2=31, Column3=0.6987730281649804, Name='Ahmad'),
#  Row(Column1=36, Column2=26, Column3=0.06459171557189858, Name='Noor'),
#  Row(Column1=95, Column2=27, Column3=0.36656607921264095, Name='Salem'),
#  Row(Column1=87, Column2=24, Column3=0.40921560132800594, Name='Ahmad'),
#  Row(Column1=98, Column2=31, Column3=0.6032982270869548, Name='Heba'),
#  Row(Column1=82, Column2=34, Column3=0.06357951987908694, Name='Heba'),
#  Row(Column1=66, Column2=28, Column3=0.6898542938518119, Name='Ahmad'),
#  Row(Column1=71, Column2=30, Column3=0.20813676438939288, Name='Ahmad'),
#  Row(Column1=46, Column2=34, Column3=0.43866673728273664, Name='Salem'),
#  Row(Column1=95, Column2=32, Column3=0.560054845842022, Name='Ahmad'),
#  Row(Column1=53, Column2=30, Column3=0.7678735904619686, Name='Noor'),
#  Row(Column1=76, Column2=26, Column3=0.8528405552800512, Name='Ahmad'),
#  Row(Column1=49, Column2=29, Column3=0.13268569987961631, Name='Salem'),
#  Row(Column1=70, Column2=30, Column3=0.12690047838799978, Name='Ahmad'),
#  Row(Column1=12, Column2=25, Column3=0.49758708607092217, Name='Salem'),
#  Row(Column1=94, Column2=32, Column3=0.5381879907460855, Name='Ahmad'),
#  Row(Column1=57, Column2=28, Column3=0.5793658134975106, Name='Ahmad'),
#  Row(Column1=86, Column2=34, Column3=0.3517157629977643, Name='Noor'),
#  Row(Column1=79, Column2=30, Column3=0.297541256417017, Name='Ahmad'),
#  Row(Column1=51, Column2=28, Column3=0.8922263734693772, Name='Heba'),
#  Row(Column1=78, Column2=34, Column3=0.7813698644010162, Name='Ahmad'),
#  Row(Column1=40, Column2=29, Column3=0.46425282624257735, Name='Heba'),
#  Row(Column1=89, Column2=26, Column3=0.7424176454764965, Name='Ahmad'),
#  Row(Column1=82, Column2=34, Column3=0.14919800703414576, Name='Ahmad'),
#  Row(Column1=24, Column2=31, Column3=0.9145313751062415, Name='Ahmad'),
#  Row(Column1=14, Column2=24, Column3=0.38389215116159814, Name='Ahmad'),
#  Row(Column1=18, Column2=24, Column3=0.9202179252570576, Name='Heba'),
#  Row(Column1=70, Column2=30, Column3=0.9109134076369031, Name='Noor'),
#  Row(Column1=96, Column2=29, Column3=0.7401181702238403, Name='Heba'),
#  Row(Column1=18, Column2=24, Column3=0.9387539586613332, Name='Ahmad'),
#  Row(Column1=89, Column2=34, Column3=0.24967627488338584, Name='Ahmad'),
#  Row(Column1=69, Column2=26, Column3=0.8526407080090577, Name='Heba'),
#  Row(Column1=80, Column2=30, Column3=0.08138134992935309, Name='Ahmad'),
#  Row(Column1=40, Column2=34, Column3=0.16957000077011597, Name='Ahmad'),
#  Row(Column1=17, Column2=24, Column3=0.3273118999348643, Name='Heba'),
#  Row(Column1=89, Column2=32, Column3=0.4866473917293228, Name='Ahmad'),
#  Row(Column1=21, Column2=24, Column3=0.6560474261920455, Name='Noor'),
#  Row(Column1=57, Column2=33, Column3=0.8390089944662844, Name='Noor'),
#  Row(Column1=81, Column2=29, Column3=0.5459170427972179, Name='Ahmad'),
#  Row(Column1=67, Column2=29, Column3=0.30853141770809933, Name='Ahmad'),
#  Row(Column1=72, Column2=24, Column3=0.9054422308213479, Name='Ahmad'),
#  Row(Column1=28, Column2=24, Column3=0.7177170560856678, Name='Salem'),
#  Row(Column1=99, Column2=31, Column3=0.11972175312405209, Name='Salem'),
#  Row(Column1=1, Column2=33, Column3=0.7221455969030186, Name='Ahmad'),
#  Row(Column1=96, Column2=25, Column3=0.014443121084453003, Name='Ahmad'),
#  Row(Column1=36, Column2=26, Column3=0.1643165530399242, Name='Salem'),
#  Row(Column1=35, Column2=24, Column3=0.5267816465530548, Name='Heba'),
#  Row(Column1=17, Column2=26, Column3=0.4053919808680758, Name='Heba'),
#  Row(Column1=73, Column2=29, Column3=0.25163982990621536, Name='Salem'),
#  Row(Column1=61, Column2=30, Column3=0.34179257339769153, Name='Ahmad'),
#  Row(Column1=89, Column2=26, Column3=0.48015191091389664, Name='Salem'),
#  Row(Column1=5, Column2=27, Column3=0.2724586481948972, Name='Ahmad'),
#  Row(Column1=37, Column2=34, Column3=0.8528782706834191, Name='Ahmad'),
#  Row(Column1=14, Column2=25, Column3=0.8121536522085969, Name='Noor'),
#  Row(Column1=93, Column2=32, Column3=0.033875714157406756, Name='Salem'),
#  Row(Column1=93, Column2=27, Column3=0.5032207130577983, Name='Ahmad'),
#  Row(Column1=15, Column2=24, Column3=0.09149208581945734, Name='Heba'),
#  Row(Column1=82, Column2=30, Column3=0.18419669280402984, Name='Heba'),
#  Row(Column1=87, Column2=27, Column3=0.8534795070800373, Name='Ahmad'),
#  Row(Column1=79, Column2=27, Column3=0.5219287905511489, Name='Salem'),
#  Row(Column1=36, Column2=26, Column3=0.8394481265431698, Name='Ahmad'),
#  Row(Column1=72, Column2=32, Column3=0.5240594956933387, Name='Ahmad'),
#  Row(Column1=50, Column2=32, Column3=0.11594081352019936, Name='Noor'),
#  Row(Column1=28, Column2=26, Column3=0.0710580007452064, Name='Noor'),
#  Row(Column1=12, Column2=34, Column3=0.08406083906413597, Name='Ahmad'),
#  Row(Column1=79, Column2=33, Column3=0.7931164915149131, Name='Ahmad'),
#  Row(Column1=65, Column2=33, Column3=0.8675819984613118, Name='Heba'),
#  Row(Column1=32, Column2=31, Column3=0.907811093421059, Name='Ahmad'),
#  Row(Column1=87, Column2=28, Column3=0.4651992585260951, Name='Ahmad'),
#  Row(Column1=74, Column2=32, Column3=0.4221385928554401, Name='Ahmad'),
#  Row(Column1=9, Column2=29, Column3=0.36763418419838534, Name='Ahmad'),
#  Row(Column1=72, Column2=28, Column3=0.452734427443371, Name='Heba'),
#  Row(Column1=66, Column2=31, Column3=0.06921138295947271, Name='Ahmad'),
#  Row(Column1=47, Column2=24, Column3=0.22337680545127736, Name='Ahmad'),
#  Row(Column1=69, Column2=34, Column3=0.2286468200589421, Name='Noor'),
#  Row(Column1=68, Column2=27, Column3=0.4365722806979532, Name='Noor'),
#  Row(Column1=4, Column2=27, Column3=0.5427312313140463, Name='Ahmad'),
#  Row(Column1=13, Column2=24, Column3=0.49058294383648116, Name='Ahmad'),
#  Row(Column1=93, Column2=31, Column3=0.17682536143929872, Name='Ahmad'),
#  Row(Column1=49, Column2=29, Column3=0.281772949522476, Name='Ahmad'),
#  Row(Column1=47, Column2=24, Column3=0.3270399264150048, Name='Ahmad'),
#  Row(Column1=38, Column2=33, Column3=0.12391257484251772, Name='Salem'),
#  Row(Column1=43, Column2=33, Column3=0.15922095262271574, Name='Heba'),
#  Row(Column1=46, Column2=29, Column3=0.36665308059899204, Name='Heba'),
#  Row(Column1=8, Column2=30, Column3=0.5771338879100333, Name='Heba'),
#  Row(Column1=52, Column2=34, Column3=0.14339931680427986, Name='Ahmad'),
#  Row(Column1=70, Column2=24, Column3=0.2105479943373907, Name='Heba'),
#  Row(Column1=66, Column2=25, Column3=0.23532347331370507, Name='Salem'),
#  Row(Column1=81, Column2=32, Column3=0.357322696471443, Name='Heba'),
#  Row(Column1=28, Column2=32, Column3=0.5137571387701534, Name='Salem'),
#  Row(Column1=13, Column2=29, Column3=0.4755204431976905, Name='Ahmad'),
#  Row(Column1=60, Column2=24, Column3=0.8959183216594475, Name='Ahmad'),
#  Row(Column1=58, Column2=32, Column3=0.04229721228091521, Name='Ahmad'),
#  Row(Column1=8, Column2=27, Column3=0.24807355479732096, Name='Ahmad'),
#  Row(Column1=79, Column2=27, Column3=0.6432795787260367, Name='Noor'),
#  Row(Column1=46, Column2=25, Column3=0.29511059968731634, Name='Heba'),
#  Row(Column1=82, Column2=30, Column3=0.037749354614967645, Name='Heba'),
#  Row(Column1=70, Column2=34, Column3=0.15089967781449376, Name='Salem'),
#  Row(Column1=30, Column2=33, Column3=0.5441402104137348, Name='Salem'),
#  Row(Column1=12, Column2=29, Column3=0.08056881652502634, Name='Ahmad'),
#  Row(Column1=63, Column2=26, Column3=0.8833145288009129, Name='Ahmad'),
#  Row(Column1=57, Column2=33, Column3=0.05020302071024463, Name='Heba'),
#  Row(Column1=76, Column2=27, Column3=0.8940651305173688, Name='Ahmad'),
#  Row(Column1=7, Column2=25, Column3=0.6194837164124694, Name='Noor'),
#  Row(Column1=26, Column2=29, Column3=0.5485034172202297, Name='Salem'),
#  Row(Column1=56, Column2=27, Column3=0.3270613724167811, Name='Ahmad'),
#  Row(Column1=15, Column2=29, Column3=0.18685569158903192, Name='Ahmad'),
#  Row(Column1=15, Column2=28, Column3=0.3175368403344925, Name='Ahmad'),
#  Row(Column1=31, Column2=31, Column3=0.0024101879603953824, Name='Heba'),
#  Row(Column1=21, Column2=24, Column3=0.12797946005704475, Name='Salem'),
#  Row(Column1=53, Column2=32, Column3=0.9483328201608371, Name='Heba'),
#  Row(Column1=3, Column2=30, Column3=0.4970571749538436, Name='Noor'),
#  Row(Column1=8, Column2=31, Column3=0.48389121928127987, Name='Heba'),
#  Row(Column1=24, Column2=33, Column3=0.37495964243593205, Name='Heba'),
#  Row(Column1=83, Column2=24, Column3=0.4708323499860284, Name='Ahmad'),
#  Row(Column1=38, Column2=29, Column3=0.1904145235605743, Name='Heba'),
#  Row(Column1=47, Column2=28, Column3=0.042714987253109404, Name='Heba'),
#  Row(Column1=13, Column2=28, Column3=0.733689358553171, Name='Ahmad'),
#  Row(Column1=63, Column2=24, Column3=0.6238452728865059, Name='Heba'),
#  Row(Column1=4, Column2=33, Column3=0.5376899572318101, Name='Ahmad'),
#  Row(Column1=55, Column2=25, Column3=0.4613498681471604, Name='Salem'),
#  Row(Column1=60, Column2=29, Column3=0.05816795536021391, Name='Heba'),
#  Row(Column1=98, Column2=27, Column3=0.2717741330105291, Name='Ahmad'),
#  Row(Column1=90, Column2=33, Column3=0.1851349896730744, Name='Noor'),
#  Row(Column1=91, Column2=24, Column3=0.29335645375952935, Name='Heba'),
#  Row(Column1=27, Column2=24, Column3=0.8021967857050529, Name='Ahmad'),
#  Row(Column1=30, Column2=25, Column3=0.9091779179708157, Name='Ahmad'),
#  Row(Column1=8, Column2=27, Column3=0.807610847975798, Name='Heba'),
#  Row(Column1=75, Column2=26, Column3=0.7448918238546167, Name='Heba'),
#  Row(Column1=51, Column2=28, Column3=0.09499953384413196, Name='Heba'),
#  Row(Column1=58, Column2=28, Column3=0.5955478729906328, Name='Ahmad'),
#  Row(Column1=60, Column2=29, Column3=0.9676640756579844, Name='Ahmad'),
#  Row(Column1=21, Column2=24, Column3=0.169209090278722, Name='Ahmad'),
#  Row(Column1=12, Column2=28, Column3=0.9616926159022136, Name='Ahmad'),
#  Row(Column1=26, Column2=31, Column3=0.38438646547120425, Name='Noor'),
#  Row(Column1=36, Column2=25, Column3=0.5629588347851596, Name='Ahmad'),
#  Row(Column1=91, Column2=32, Column3=0.8396760552697645, Name='Ahmad'),
#  Row(Column1=80, Column2=31, Column3=0.231898044398134, Name='Ahmad'),
#  Row(Column1=18, Column2=34, Column3=0.4270034837015385, Name='Ahmad'),
#  Row(Column1=61, Column2=27, Column3=0.3664093252050086, Name='Ahmad'),
#  Row(Column1=64, Column2=24, Column3=0.2710687038681342, Name='Salem'),
#  Row(Column1=71, Column2=27, Column3=0.9346176416890862, Name='Noor'),
#  Row(Column1=15, Column2=25, Column3=0.27055273652015854, Name='Ahmad'),
#  Row(Column1=97, Column2=30, Column3=0.9266740749158565, Name='Ahmad'),
#  Row(Column1=7, Column2=29, Column3=0.20519197214131357, Name='Heba'),
#  Row(Column1=76, Column2=25, Column3=0.3159469018358134, Name='Ahmad'),
#  Row(Column1=85, Column2=31, Column3=0.12748200571085322, Name='Ahmad'),
#  Row(Column1=39, Column2=32, Column3=0.9921922691543963, Name='Heba'),
#  Row(Column1=12, Column2=24, Column3=0.3571939319581149, Name='Ahmad'),
#  Row(Column1=30, Column2=24, Column3=0.9467966264441786, Name='Ahmad'),
#  Row(Column1=36, Column2=34, Column3=0.612312485149557, Name='Salem'),
#  Row(Column1=35, Column2=27, Column3=0.013818631519820324, Name='Heba'),
#  Row(Column1=46, Column2=24, Column3=0.6762549173754542, Name='Ahmad'),
#  Row(Column1=92, Column2=29, Column3=0.320208789219533, Name='Noor'),
#  Row(Column1=70, Column2=28, Column3=0.9508565890892023, Name='Ahmad'),
#  Row(Column1=93, Column2=32, Column3=0.4303340259746966, Name='Ahmad'),
#  Row(Column1=97, Column2=28, Column3=0.9370323151633476, Name='Noor'),
#  Row(Column1=36, Column2=31, Column3=0.6105841925164298, Name='Ahmad'),
#  Row(Column1=45, Column2=29, Column3=0.4443702490371926, Name='Heba'),
#  Row(Column1=16, Column2=25, Column3=0.7625628153247876, Name='Heba'),
#  Row(Column1=90, Column2=31, Column3=0.9022381183455471, Name='Ahmad'),
#  Row(Column1=95, Column2=25, Column3=0.6157349485236767, Name='Ahmad'),
#  Row(Column1=93, Column2=29, Column3=0.22666645665488783, Name='Salem'),
#  Row(Column1=64, Column2=25, Column3=0.9612318912435501, Name='Salem'),
#  Row(Column1=83, Column2=32, Column3=0.6928725652247623, Name='Ahmad'),
#  Row(Column1=8, Column2=30, Column3=0.4430059349208697, Name='Salem'),
#  Row(Column1=37, Column2=27, Column3=0.5924455099345505, Name='Heba'),
#  Row(Column1=71, Column2=30, Column3=0.08008657684151732, Name='Heba'),
#  Row(Column1=66, Column2=27, Column3=0.6377695281146059, Name='Salem'),
#  Row(Column1=53, Column2=24, Column3=0.20059030162410407, Name='Ahmad'),
#  Row(Column1=65, Column2=27, Column3=0.19795235285677926, Name='Heba'),
#  Row(Column1=41, Column2=30, Column3=0.890334469812203, Name='Ahmad'),
#  Row(Column1=16, Column2=34, Column3=0.24274505122191314, Name='Ahmad'),
#  Row(Column1=18, Column2=32, Column3=0.20579668075832824, Name='Heba'),
#  Row(Column1=28, Column2=34, Column3=0.6609509997594879, Name='Ahmad'),
#  Row(Column1=91, Column2=29, Column3=0.2898012192876329, Name='Ahmad'),
#  Row(Column1=19, Column2=29, Column3=0.4767252395773979, Name='Noor'),
#  Row(Column1=31, Column2=26, Column3=0.3110923021859424, Name='Heba'),
#  Row(Column1=5, Column2=32, Column3=0.8473102023174185, Name='Ahmad'),
#  Row(Column1=77, Column2=33, Column3=0.17085901416558424, Name='Salem'),
#  Row(Column1=33, Column2=26, Column3=0.2244938938997737, Name='Noor'),
#  Row(Column1=77, Column2=24, Column3=0.1591854102293273, Name='Heba'),
#  Row(Column1=5, Column2=28, Column3=0.886509466688857, Name='Salem'),
#  Row(Column1=12, Column2=26, Column3=0.3222243318563739, Name='Heba'),
#  Row(Column1=57, Column2=27, Column3=0.34145782341091735, Name='Ahmad'),
#  Row(Column1=82, Column2=29, Column3=0.9330776657703342, Name='Salem'),
#  Row(Column1=14, Column2=27, Column3=0.014616967537314451, Name='Salem'),
#  Row(Column1=76, Column2=33, Column3=0.32398732937046204, Name='Noor'),
#  Row(Column1=87, Column2=28, Column3=0.7443223827705261, Name='Ahmad'),
#  Row(Column1=29, Column2=32, Column3=0.48979443728006733, Name='Ahmad'),
#  Row(Column1=73, Column2=33, Column3=0.9991036296931801, Name='Ahmad'),
#  Row(Column1=76, Column2=28, Column3=0.17546822908151238, Name='Ahmad'),
#  Row(Column1=25, Column2=24, Column3=0.2645834666444775, Name='Heba'),
#  Row(Column1=71, Column2=30, Column3=0.5259147322496447, Name='Salem'),
#  Row(Column1=40, Column2=32, Column3=0.8544337520315323, Name='Salem'),
#  Row(Column1=74, Column2=30, Column3=0.6094944964567015, Name='Salem'),
#  Row(Column1=25, Column2=30, Column3=0.12123295409962831, Name='Noor'),
#  Row(Column1=92, Column2=26, Column3=0.6566853862912012, Name='Heba'),
#  Row(Column1=72, Column2=30, Column3=0.844322569064542, Name='Ahmad'),
#  Row(Column1=39, Column2=32, Column3=0.09350405507904713, Name='Ahmad'),
#  Row(Column1=77, Column2=30, Column3=0.5850669047084808, Name='Heba'),
#  Row(Column1=61, Column2=34, Column3=0.2801074723586613, Name='Ahmad'),
#  Row(Column1=49, Column2=30, Column3=0.8689077024791125, Name='Ahmad'),
#  Row(Column1=29, Column2=32, Column3=0.7317697630640025, Name='Ahmad'),
#  Row(Column1=6, Column2=31, Column3=0.28506057620097147, Name='Ahmad'),
#  Row(Column1=91, Column2=28, Column3=0.6773378037573876, Name='Ahmad'),
#  Row(Column1=23, Column2=33, Column3=0.9282866102282428, Name='Ahmad'),
#  Row(Column1=14, Column2=30, Column3=0.08016078685969397, Name='Noor'),
#  Row(Column1=12, Column2=30, Column3=0.3502154782118503, Name='Ahmad'),
#  Row(Column1=9, Column2=28, Column3=0.409029034638451, Name='Ahmad'),
#  Row(Column1=84, Column2=29, Column3=0.27564281723938844, Name='Ahmad'),
#  Row(Column1=84, Column2=24, Column3=0.2714930574037099, Name='Heba'),
#  Row(Column1=86, Column2=32, Column3=0.051892400991134124, Name='Heba'),
#  Row(Column1=78, Column2=29, Column3=0.9992195440304341, Name='Heba'),
#  Row(Column1=37, Column2=32, Column3=0.501741036588641, Name='Ahmad'),
#  Row(Column1=18, Column2=25, Column3=0.8012804963189054, Name='Heba'),
#  Row(Column1=57, Column2=31, Column3=0.9803609154408534, Name='Salem'),
#  Row(Column1=57, Column2=30, Column3=0.6104545812818924, Name='Ahmad'),
#  Row(Column1=9, Column2=29, Column3=0.8697920605659628, Name='Ahmad'),
#  Row(Column1=87, Column2=32, Column3=0.6566483727120789, Name='Ahmad'),
#  Row(Column1=99, Column2=32, Column3=0.9510338019960769, Name='Noor'),
#  Row(Column1=3, Column2=30, Column3=0.9770470984758463, Name='Ahmad'),
#  Row(Column1=78, Column2=29, Column3=0.8261282543249168, Name='Salem'),
#  Row(Column1=55, Column2=28, Column3=0.03578294810754146, Name='Heba'),
#  Row(Column1=40, Column2=30, Column3=0.16532488313768634, Name='Ahmad'),
#  Row(Column1=94, Column2=24, Column3=0.6492968844143846, Name='Salem'),
#  Row(Column1=21, Column2=25, Column3=0.5241487926682613, Name='Salem'),
#  Row(Column1=60, Column2=26, Column3=0.014271089397144388, Name='Salem'),
#  Row(Column1=30, Column2=24, Column3=0.8264227190169884, Name='Ahmad'),
#  Row(Column1=8, Column2=24, Column3=0.322813748473742, Name='Ahmad'),
#  Row(Column1=2, Column2=30, Column3=0.9167007216032796, Name='Ahmad'),
#  Row(Column1=71, Column2=34, Column3=0.37098137302627987, Name='Heba'),
#  Row(Column1=97, Column2=30, Column3=0.37627765413574543, Name='Ahmad'),
#  Row(Column1=61, Column2=33, Column3=0.43753459427589636, Name='Salem'),
#  Row(Column1=44, Column2=24, Column3=0.04429118824286882, Name='Salem'),
#  Row(Column1=7, Column2=24, Column3=0.9572557861364251, Name='Noor'),
#  Row(Column1=22, Column2=30, Column3=0.2578314871289149, Name='Heba'),
#  Row(Column1=43, Column2=32, Column3=0.7470703949310342, Name='Ahmad'),
#  Row(Column1=39, Column2=29, Column3=0.24815726659346082, Name='Heba'),
#  Row(Column1=82, Column2=29, Column3=0.6635053713891772, Name='Heba'),
#  Row(Column1=65, Column2=29, Column3=0.31450432943780215, Name='Noor'),
#  Row(Column1=33, Column2=29, Column3=0.2605291889487237, Name='Ahmad'),
#  Row(Column1=52, Column2=34, Column3=0.8146847833727713, Name='Salem'),
#  Row(Column1=36, Column2=27, Column3=0.6534619046492618, Name='Ahmad'),
#  Row(Column1=36, Column2=31, Column3=0.6689585744750659, Name='Heba'),
#  Row(Column1=38, Column2=28, Column3=0.6499507646176678, Name='Ahmad'),
#  Row(Column1=97, Column2=34, Column3=0.7749097672975664, Name='Ahmad'),
#  Row(Column1=56, Column2=29, Column3=0.6573412259648926, Name='Noor'),
#  Row(Column1=85, Column2=26, Column3=0.018275528880822955, Name='Noor'),
#  Row(Column1=20, Column2=27, Column3=0.04395075510822499, Name='Noor'),
#  Row(Column1=36, Column2=24, Column3=0.05714788773787227, Name='Ahmad'),
#  Row(Column1=94, Column2=32, Column3=0.9782739027825282, Name='Heba'),
#  Row(Column1=26, Column2=30, Column3=0.5284798942319384, Name='Salem'),
#  Row(Column1=36, Column2=24, Column3=0.872066948062475, Name='Salem'),
#  Row(Column1=99, Column2=28, Column3=0.4613653003235362, Name='Ahmad'),
#  Row(Column1=70, Column2=32, Column3=0.37294269759912724, Name='Salem'),
#  Row(Column1=97, Column2=26, Column3=0.5416426352993796, Name='Heba'),
#  Row(Column1=39, Column2=30, Column3=0.8913050942152039, Name='Salem'),
#  Row(Column1=62, Column2=28, Column3=0.9183772799595448, Name='Heba'),
#  Row(Column1=57, Column2=29, Column3=0.17987231443901963, Name='Ahmad'),
#  Row(Column1=56, Column2=33, Column3=0.45403635670861175, Name='Ahmad'),
#  Row(Column1=43, Column2=32, Column3=0.8604244481094151, Name='Ahmad'),
#  Row(Column1=85, Column2=33, Column3=0.9379308212016422, Name='Heba'),
#  Row(Column1=90, Column2=26, Column3=0.3996708151248909, Name='Noor'),
#  Row(Column1=30, Column2=32, Column3=0.034201681903311965, Name='Heba'),
#  Row(Column1=56, Column2=27, Column3=0.47328903931509847, Name='Ahmad'),
#  Row(Column1=4, Column2=30, Column3=0.3704008102087437, Name='Ahmad'),
#  Row(Column1=9, Column2=30, Column3=0.7180065568084152, Name='Salem'),
#  Row(Column1=22, Column2=24, Column3=0.5318222647331258, Name='Salem'),
#  Row(Column1=23, Column2=34, Column3=0.33939113543651744, Name='Ahmad'),
#  Row(Column1=39, Column2=26, Column3=0.537911950400284, Name='Ahmad'),
#  Row(Column1=8, Column2=31, Column3=0.4085258623075074, Name='Salem'),
#  Row(Column1=22, Column2=32, Column3=0.4265020309712848, Name='Ahmad'),
#  Row(Column1=16, Column2=24, Column3=0.007435332224713931, Name='Salem'),
#  Row(Column1=73, Column2=30, Column3=0.05437375471277495, Name='Ahmad'),
#  Row(Column1=27, Column2=24, Column3=0.760147946759412, Name='Salem'),
#  Row(Column1=40, Column2=24, Column3=0.9321280001934482, Name='Ahmad'),
#  Row(Column1=55, Column2=33, Column3=0.6308238181595307, Name='Ahmad'),
#  Row(Column1=43, Column2=24, Column3=0.6746003997082306, Name='Heba'),
#  Row(Column1=54, Column2=26, Column3=0.20514824560706835, Name='Heba'),
#  Row(Column1=8, Column2=25, Column3=0.3725188209015986, Name='Heba'),
#  Row(Column1=2, Column2=33, Column3=0.5996472219534655, Name='Ahmad'),
#  Row(Column1=66, Column2=29, Column3=0.9993267042904767, Name='Salem'),
#  Row(Column1=31, Column2=26, Column3=0.9214243092449592, Name='Heba'),
#  Row(Column1=48, Column2=24, Column3=0.957420570778876, Name='Heba'),
#  Row(Column1=12, Column2=34, Column3=0.8130373375503063, Name='Noor'),
#  Row(Column1=17, Column2=30, Column3=0.8994359829424972, Name='Ahmad'),
#  Row(Column1=15, Column2=24, Column3=0.953943868291494, Name='Heba'),
#  Row(Column1=74, Column2=25, Column3=0.17283713585305682, Name='Noor'),
#  Row(Column1=23, Column2=26, Column3=0.4260812294521158, Name='Ahmad'),
#  Row(Column1=93, Column2=28, Column3=0.7043285694885169, Name='Noor'),
#  Row(Column1=76, Column2=29, Column3=0.3043608158118102, Name='Ahmad'),
#  Row(Column1=90, Column2=30, Column3=0.3728079893043539, Name='Salem'),
#  Row(Column1=28, Column2=27, Column3=0.4657825406108633, Name='Ahmad'),
#  Row(Column1=10, Column2=26, Column3=0.5063312303095469, Name='Ahmad'),
#  Row(Column1=65, Column2=28, Column3=0.07019628345054985, Name='Salem'),
#  Row(Column1=54, Column2=31, Column3=0.29850735017680163, Name='Ahmad'),
#  Row(Column1=40, Column2=33, Column3=0.807766578289213, Name='Ahmad'),
#  Row(Column1=53, Column2=27, Column3=0.40888153871503186, Name='Salem'),
#  Row(Column1=18, Column2=31, Column3=0.48221405190156463, Name='Ahmad'),
#  Row(Column1=93, Column2=31, Column3=0.5201174579787158, Name='Heba'),
#  Row(Column1=63, Column2=34, Column3=0.8790430010611223, Name='Heba'),
#  Row(Column1=9, Column2=31, Column3=0.20908054374504292, Name='Heba'),
#  Row(Column1=4, Column2=30, Column3=0.5981752974881012, Name='Noor'),
#  Row(Column1=69, Column2=26, Column3=0.7493075452190895, Name='Heba'),
#  Row(Column1=52, Column2=24, Column3=0.9005447178616292, Name='Ahmad'),
#  Row(Column1=39, Column2=32, Column3=0.8018167191339747, Name='Ahmad'),
#  Row(Column1=8, Column2=30, Column3=0.5279364769589779, Name='Ahmad'),
#  Row(Column1=21, Column2=33, Column3=0.9815232769297935, Name='Ahmad'),
#  Row(Column1=31, Column2=29, Column3=0.4441108563690197, Name='Ahmad'),
#  Row(Column1=26, Column2=30, Column3=0.6730716175973447, Name='Noor'),
#  Row(Column1=6, Column2=25, Column3=0.6051562118969402, Name='Ahmad'),
#  Row(Column1=76, Column2=27, Column3=0.8633941220249856, Name='Ahmad'),
#  Row(Column1=23, Column2=29, Column3=0.9645424510366198, Name='Ahmad'),
#  Row(Column1=51, Column2=31, Column3=0.07726407354512699, Name='Salem'),
#  Row(Column1=70, Column2=28, Column3=0.339244117112536, Name='Ahmad'),
#  Row(Column1=2, Column2=32, Column3=0.3003149007013526, Name='Ahmad'),
#  Row(Column1=30, Column2=25, Column3=0.9544340033771829, Name='Heba'),
#  Row(Column1=60, Column2=33, Column3=0.09604548746387886, Name='Salem'),
#  Row(Column1=80, Column2=33, Column3=0.16728967001967465, Name='Ahmad'),
#  Row(Column1=9, Column2=32, Column3=0.7584381137124481, Name='Ahmad'),
#  Row(Column1=50, Column2=27, Column3=0.12222010002254025, Name='Heba'),
#  Row(Column1=20, Column2=31, Column3=0.8332575029858429, Name='Salem'),
#  Row(Column1=16, Column2=30, Column3=0.3177211658993355, Name='Salem'),
#  Row(Column1=46, Column2=33, Column3=0.10772519601730168, Name='Noor'),
#  Row(Column1=87, Column2=27, Column3=0.0317441156904269, Name='Heba'),
#  Row(Column1=69, Column2=27, Column3=0.26775426748945075, Name='Ahmad'),
#  Row(Column1=51, Column2=33, Column3=0.4834689838208539, Name='Heba'),
#  Row(Column1=41, Column2=31, Column3=0.6846405806039757, Name='Ahmad'),
#  Row(Column1=12, Column2=26, Column3=0.9701539937971965, Name='Ahmad'),
#  Row(Column1=58, Column2=27, Column3=0.5455644792452388, Name='Ahmad'),
#  Row(Column1=85, Column2=28, Column3=0.6921541629931143, Name='Heba'),
#  Row(Column1=42, Column2=29, Column3=0.50935401709067, Name='Heba'),
#  Row(Column1=4, Column2=26, Column3=0.37135238574939844, Name='Ahmad'),
#  Row(Column1=1, Column2=28, Column3=0.4963321188950979, Name='Heba'),
#  Row(Column1=2, Column2=34, Column3=0.18208128337974783, Name='Ahmad'),
#  Row(Column1=20, Column2=24, Column3=0.34207026999123114, Name='Ahmad'),
#  Row(Column1=71, Column2=24, Column3=0.9286922161493723, Name='Salem'),
#  Row(Column1=48, Column2=34, Column3=0.4201493186890167, Name='Salem'),
#  Row(Column1=16, Column2=26, Column3=0.20413493032548047, Name='Heba'),
#  Row(Column1=61, Column2=29, Column3=0.7432837311024084, Name='Heba'),
#  Row(Column1=54, Column2=33, Column3=0.3524924160670182, Name='Ahmad'),
#  Row(Column1=83, Column2=27, Column3=0.4532637493995656, Name='Heba'),
#  Row(Column1=58, Column2=29, Column3=0.7230697229538108, Name='Ahmad'),
#  Row(Column1=39, Column2=26, Column3=0.07984942426864616, Name='Heba'),
#  Row(Column1=81, Column2=27, Column3=0.23150276799105463, Name='Ahmad'),
#  Row(Column1=57, Column2=34, Column3=0.35781738856410783, Name='Heba'),
#  Row(Column1=72, Column2=27, Column3=0.1570183360034033, Name='Heba'),
#  Row(Column1=60, Column2=34, Column3=0.777556522265026, Name='Salem'),
#  Row(Column1=41, Column2=27, Column3=0.743854682867615, Name='Salem'),
#  Row(Column1=93, Column2=28, Column3=0.014792978274937085, Name='Ahmad'),
#  Row(Column1=52, Column2=34, Column3=0.25700925897572013, Name='Heba'),
#  Row(Column1=24, Column2=29, Column3=0.3528026255295852, Name='Ahmad'),
#  Row(Column1=67, Column2=30, Column3=0.22156842687268985, Name='Heba'),
#  Row(Column1=51, Column2=24, Column3=0.06234648215888594, Name='Heba'),
#  Row(Column1=37, Column2=24, Column3=0.6798183632687106, Name='Ahmad'),
#  Row(Column1=29, Column2=27, Column3=0.5954510829316684, Name='Ahmad'),
#  Row(Column1=33, Column2=30, Column3=0.7978998633321254, Name='Ahmad'),
#  Row(Column1=27, Column2=28, Column3=0.10283560510372292, Name='Ahmad'),
#  Row(Column1=8, Column2=25, Column3=0.0829793982589404, Name='Ahmad'),
#  Row(Column1=34, Column2=24, Column3=0.7990697290624756, Name='Heba'),
#  Row(Column1=6, Column2=32, Column3=0.1233176272533959, Name='Ahmad'),
#  Row(Column1=45, Column2=28, Column3=0.36211991204093263, Name='Ahmad'),
#  Row(Column1=2, Column2=33, Column3=0.9121978519649889, Name='Heba'),
#  Row(Column1=6, Column2=31, Column3=0.9285499479230948, Name='Salem'),
#  Row(Column1=40, Column2=29, Column3=0.8988403230777986, Name='Salem'),
#  Row(Column1=15, Column2=33, Column3=0.3073241203583891, Name='Ahmad'),
#  Row(Column1=73, Column2=26, Column3=0.9429936966410516, Name='Heba'),
#  Row(Column1=18, Column2=34, Column3=0.017719484461171997, Name='Noor'),
#  Row(Column1=90, Column2=24, Column3=0.2701539956752599, Name='Salem'),
#  Row(Column1=96, Column2=31, Column3=0.8550013476112234, Name='Ahmad'),
#  Row(Column1=46, Column2=29, Column3=0.04341162967527945, Name='Heba'),
#  Row(Column1=52, Column2=24, Column3=0.5389783999681732, Name='Salem'),
#  Row(Column1=8, Column2=27, Column3=0.543646787870957, Name='Ahmad'),
#  Row(Column1=88, Column2=34, Column3=0.7908333579040555, Name='Salem'),
#  Row(Column1=12, Column2=24, Column3=0.7496320835208228, Name='Ahmad'),
#  Row(Column1=33, Column2=25, Column3=0.48754470331722743, Name='Salem'),
#  Row(Column1=90, Column2=30, Column3=0.630809278261354, Name='Heba'),
#  Row(Column1=55, Column2=24, Column3=0.3759650511470306, Name='Salem'),
#  Row(Column1=44, Column2=33, Column3=0.2870736972631618, Name='Salem'),
#  Row(Column1=74, Column2=34, Column3=0.08726604899348012, Name='Ahmad'),
#  Row(Column1=72, Column2=28, Column3=0.7003269390164718, Name='Heba'),
#  Row(Column1=31, Column2=33, Column3=0.8454809405674631, Name='Noor'),
#  Row(Column1=92, Column2=34, Column3=0.008487101419905274, Name='Salem'),
#  Row(Column1=80, Column2=27, Column3=0.4346107560325956, Name='Ahmad'),
#  Row(Column1=39, Column2=30, Column3=0.8952201082059574, Name='Noor'),
#  Row(Column1=57, Column2=33, Column3=0.5830191023368528, Name='Ahmad'),
# ...
#  Row(Column1=84, Column2=33, Column3=0.47810730278311087, Name='Ahmad'),
#  Row(Column1=34, Column2=30, Column3=0.9903907162863171, Name='Noor'),
#  Row(Column1=69, Column2=33, Column3=0.6615457527793364, Name='Ahmad'),
#  Row(Column1=70, Column2=29, Column3=0.7297311245682954, Name='Heba'),
#  Row(Column1=26, Column2=29, Column3=0.9783078086934852, Name='Heba'),
#  Row(Column1=98, Column2=27, Column3=0.5779692239843592, Name='Ahmad'),
#  Row(Column1=67, Column2=28, Column3=0.70142023815428, Name='Heba'),
#  Row(Column1=47, Column2=32, Column3=0.14302494257408194, Name='Ahmad'),
#  Row(Column1=94, Column2=34, Column3=0.7935854314601437, Name='Ahmad'),
#  Row(Column1=42, Column2=30, Column3=0.1225688554162242, Name='Salem'),
#  Row(Column1=4, Column2=33, Column3=0.3215815683926405, Name='Salem'),
#  Row(Column1=71, Column2=32, Column3=0.8094931617597274, Name='Heba'),
#  Row(Column1=62, Column2=27, Column3=0.6813977815018594, Name='Salem'),
#  Row(Column1=85, Column2=26, Column3=0.4332909526979718, Name='Noor'),
#  Row(Column1=19, Column2=31, Column3=0.36055737403864796, Name='Heba'),
#  Row(Column1=98, Column2=29, Column3=0.7538334478750577, Name='Ahmad'),
#  Row(Column1=38, Column2=31, Column3=0.36844059939186313, Name='Salem'),
#  Row(Column1=78, Column2=31, Column3=0.4532450565744328, Name='Ahmad'),
#  Row(Column1=42, Column2=32, Column3=0.7424701056168901, Name='Ahmad'),
#  Row(Column1=36, Column2=27, Column3=0.362661627448279, Name='Ahmad'),
#  Row(Column1=30, Column2=25, Column3=0.34476167944168, Name='Noor'),
#  Row(Column1=45, Column2=29, Column3=0.9540218513226347, Name='Ahmad'),
#  Row(Column1=55, Column2=25, Column3=0.6064964839028675, Name='Ahmad'),
#  Row(Column1=52, Column2=33, Column3=0.5332884066846376, Name='Noor'),
#  Row(Column1=4, Column2=29, Column3=0.8717034280054565, Name='Ahmad'),
#  Row(Column1=14, Column2=27, Column3=0.2535213376959442, Name='Ahmad'),
#  Row(Column1=18, Column2=33, Column3=0.6490098426134617, Name='Ahmad'),
#  Row(Column1=19, Column2=29, Column3=0.028114580682424672, Name='Noor'),
#  Row(Column1=47, Column2=28, Column3=0.7651083666055551, Name='Ahmad'),
#  Row(Column1=83, Column2=32, Column3=0.09652640057952877, Name='Heba'),
#  Row(Column1=42, Column2=32, Column3=0.9914587214325291, Name='Noor'),
#  Row(Column1=1, Column2=26, Column3=0.32851591525744206, Name='Ahmad'),
#  Row(Column1=85, Column2=26, Column3=0.6673852140905426, Name='Heba'),
#  Row(Column1=55, Column2=26, Column3=0.8941115020917509, Name='Salem'),
#  Row(Column1=11, Column2=26, Column3=0.27852729399296716, Name='Salem'),
#  Row(Column1=48, Column2=32, Column3=0.5019989052201383, Name='Ahmad'),
#  Row(Column1=16, Column2=29, Column3=0.580677063197527, Name='Salem'),
#  Row(Column1=71, Column2=25, Column3=0.09850591390374497, Name='Noor'),
#  Row(Column1=16, Column2=31, Column3=0.10230298522759929, Name='Heba'),
#  Row(Column1=30, Column2=30, Column3=0.3175286571717416, Name='Ahmad'),
#  Row(Column1=49, Column2=34, Column3=0.597019778122066, Name='Ahmad'),
#  Row(Column1=67, Column2=33, Column3=0.49389057720342977, Name='Salem'),
#  Row(Column1=51, Column2=29, Column3=0.8701911833916782, Name='Noor'),
#  Row(Column1=38, Column2=27, Column3=0.7263469363609071, Name='Ahmad'),
#  Row(Column1=86, Column2=27, Column3=0.24333988634666404, Name='Heba'),
#  Row(Column1=91, Column2=27, Column3=0.09712008650132398, Name='Heba'),
#  Row(Column1=76, Column2=26, Column3=0.39599278276033656, Name='Ahmad'),
#  Row(Column1=25, Column2=29, Column3=0.5494426129599187, Name='Noor'),
#  Row(Column1=74, Column2=27, Column3=0.16385566156370712, Name='Ahmad'),
#  Row(Column1=55, Column2=31, Column3=0.520796995179855, Name='Ahmad'),
#  Row(Column1=96, Column2=26, Column3=0.9602070380967048, Name='Heba'),
#  Row(Column1=67, Column2=28, Column3=0.21002944657133638, Name='Heba'),
#  Row(Column1=54, Column2=32, Column3=0.932718975679502, Name='Ahmad'),
#  Row(Column1=81, Column2=30, Column3=0.39310941385702103, Name='Ahmad'),
#  Row(Column1=83, Column2=30, Column3=0.7839147011991988, Name='Heba'),
#  Row(Column1=66, Column2=29, Column3=0.8762044174403879, Name='Heba'),
#  Row(Column1=22, Column2=32, Column3=0.12189154804819957, Name='Heba'),
#  Row(Column1=86, Column2=29, Column3=0.36446371208177597, Name='Ahmad'),
#  Row(Column1=44, Column2=33, Column3=0.5747395251614653, Name='Ahmad'),
#  Row(Column1=98, Column2=34, Column3=0.0016562402104007834, Name='Noor'),
#  Row(Column1=10, Column2=24, Column3=0.2924902135560198, Name='Ahmad'),
#  Row(Column1=4, Column2=25, Column3=0.7119391734872028, Name='Heba'),
#  Row(Column1=32, Column2=27, Column3=0.22835431191824618, Name='Ahmad'),
#  Row(Column1=2, Column2=33, Column3=0.7255330750174082, Name='Salem'),
#  Row(Column1=37, Column2=32, Column3=0.4145412918410606, Name='Ahmad'),
#  Row(Column1=90, Column2=27, Column3=0.8292669944365926, Name='Ahmad'),
#  Row(Column1=39, Column2=24, Column3=0.07839732023357415, Name='Ahmad'),
#  Row(Column1=4, Column2=30, Column3=0.9852442929792199, Name='Ahmad'),
#  Row(Column1=14, Column2=28, Column3=0.7909457114020134, Name='Salem'),
#  Row(Column1=26, Column2=25, Column3=0.38399768255087585, Name='Ahmad'),
#  Row(Column1=7, Column2=26, Column3=0.07092629226610148, Name='Ahmad'),
#  Row(Column1=62, Column2=31, Column3=0.3101366475559699, Name='Salem'),
#  Row(Column1=78, Column2=34, Column3=0.936778599276553, Name='Ahmad'),
#  Row(Column1=85, Column2=34, Column3=0.021630646406867182, Name='Ahmad'),
#  Row(Column1=97, Column2=28, Column3=0.12252213339268869, Name='Ahmad'),
#  Row(Column1=22, Column2=33, Column3=0.9669819853150446, Name='Ahmad'),
#  Row(Column1=64, Column2=34, Column3=0.9275375868972184, Name='Heba'),
#  Row(Column1=26, Column2=28, Column3=0.8243563120398074, Name='Ahmad'),
#  Row(Column1=79, Column2=25, Column3=0.10783683611002504, Name='Ahmad'),
#  Row(Column1=16, Column2=34, Column3=0.44963107392107116, Name='Heba'),
#  Row(Column1=53, Column2=34, Column3=0.6705306873959892, Name='Heba'),
#  Row(Column1=62, Column2=26, Column3=0.9192493877401579, Name='Salem'),
#  Row(Column1=94, Column2=30, Column3=0.3799910672163279, Name='Heba'),
#  Row(Column1=95, Column2=29, Column3=0.8452401969906079, Name='Ahmad'),
#  Row(Column1=40, Column2=29, Column3=0.7489155002998047, Name='Ahmad'),
#  Row(Column1=48, Column2=32, Column3=0.43200366554002734, Name='Heba'),
#  Row(Column1=91, Column2=26, Column3=0.8187568657502173, Name='Salem'),
#  Row(Column1=45, Column2=33, Column3=0.974823870268171, Name='Heba'),
#  Row(Column1=53, Column2=26, Column3=0.003241094084170948, Name='Noor'),
#  Row(Column1=32, Column2=27, Column3=0.27916007280630395, Name='Ahmad'),
#  Row(Column1=53, Column2=27, Column3=0.44838189669112694, Name='Salem'),
#  Row(Column1=97, Column2=34, Column3=0.5257898550978652, Name='Heba'),
#  Row(Column1=12, Column2=25, Column3=0.4256231529118375, Name='Heba'),
#  Row(Column1=37, Column2=28, Column3=0.35340547632102115, Name='Salem'),
#  Row(Column1=18, Column2=34, Column3=0.937918691741515, Name='Ahmad'),
#  Row(Column1=1, Column2=30, Column3=0.4467731617787287, Name='Ahmad'),
#  Row(Column1=84, Column2=28, Column3=0.16531889712766412, Name='Heba'),
#  Row(Column1=19, Column2=28, Column3=0.14550727913286, Name='Ahmad'),
#  Row(Column1=16, Column2=28, Column3=0.5240743471463526, Name='Ahmad'),
#  Row(Column1=62, Column2=29, Column3=0.0280345439752947, Name='Ahmad'),
#  Row(Column1=59, Column2=25, Column3=0.033221544413161386, Name='Ahmad'),
#  Row(Column1=11, Column2=29, Column3=0.6157394076045947, Name='Salem'),
#  Row(Column1=39, Column2=29, Column3=0.687420274794154, Name='Ahmad'),
#  Row(Column1=95, Column2=24, Column3=0.6765597579094574, Name='Heba'),
#  Row(Column1=42, Column2=31, Column3=0.9792030308819996, Name='Noor'),
#  Row(Column1=85, Column2=31, Column3=0.7367453945001825, Name='Ahmad'),
#  Row(Column1=94, Column2=26, Column3=0.3744514620227237, Name='Noor'),
#  Row(Column1=19, Column2=29, Column3=0.6422768078481043, Name='Heba'),
#  Row(Column1=12, Column2=24, Column3=0.1403947634554158, Name='Salem'),
#  Row(Column1=68, Column2=29, Column3=0.5169996315429841, Name='Heba'),
#  Row(Column1=16, Column2=32, Column3=0.30554108172015104, Name='Ahmad'),
#  Row(Column1=49, Column2=25, Column3=0.7663940603295926, Name='Noor'),
#  Row(Column1=59, Column2=24, Column3=0.2713980094174684, Name='Noor'),
#  Row(Column1=99, Column2=24, Column3=0.26826849837849753, Name='Salem'),
#  Row(Column1=56, Column2=34, Column3=0.7934552477298049, Name='Salem'),
#  Row(Column1=9, Column2=30, Column3=0.8114798681651437, Name='Ahmad'),
#  Row(Column1=53, Column2=27, Column3=0.24222283420885216, Name='Ahmad'),
#  Row(Column1=17, Column2=33, Column3=0.9509417166888924, Name='Ahmad'),
#  Row(Column1=40, Column2=32, Column3=0.6147840612157617, Name='Noor'),
#  Row(Column1=48, Column2=26, Column3=0.5470271801871046, Name='Ahmad'),
#  Row(Column1=23, Column2=24, Column3=0.8862771694517714, Name='Heba'),
#  Row(Column1=93, Column2=34, Column3=0.4023939434435212, Name='Heba'),
#  Row(Column1=82, Column2=29, Column3=0.8027852046782731, Name='Ahmad'),
#  Row(Column1=74, Column2=26, Column3=0.3930707115147023, Name='Ahmad'),
#  Row(Column1=86, Column2=27, Column3=0.13895077137369338, Name='Ahmad'),
#  Row(Column1=63, Column2=29, Column3=0.7668850461804737, Name='Salem'),
#  Row(Column1=47, Column2=24, Column3=0.9462981025834752, Name='Heba'),
#  Row(Column1=80, Column2=32, Column3=0.06631789274177236, Name='Noor'),
#  Row(Column1=27, Column2=28, Column3=0.7668940217346472, Name='Ahmad'),
#  Row(Column1=32, Column2=28, Column3=0.48628622829863255, Name='Salem'),
#  Row(Column1=19, Column2=32, Column3=0.09651629846978294, Name='Noor'),
#  Row(Column1=98, Column2=29, Column3=0.5539486679616349, Name='Heba'),
#  Row(Column1=38, Column2=27, Column3=0.37523748407336155, Name='Noor'),
#  Row(Column1=14, Column2=24, Column3=0.4310276566703374, Name='Noor'),
#  Row(Column1=62, Column2=27, Column3=0.3051420464676171, Name='Ahmad'),
#  Row(Column1=1, Column2=25, Column3=0.3778955267190205, Name='Ahmad'),
#  Row(Column1=50, Column2=24, Column3=0.911185800965953, Name='Salem'),
#  Row(Column1=22, Column2=27, Column3=0.13231097362281208, Name='Heba'),
#  Row(Column1=71, Column2=24, Column3=0.7578136959682757, Name='Ahmad'),
#  Row(Column1=4, Column2=27, Column3=0.508009428430402, Name='Ahmad'),
#  Row(Column1=27, Column2=28, Column3=0.28957652289260927, Name='Ahmad'),
#  Row(Column1=28, Column2=30, Column3=0.8207965772876855, Name='Salem'),
#  Row(Column1=88, Column2=34, Column3=0.5905088445569436, Name='Ahmad'),
#  Row(Column1=40, Column2=26, Column3=0.3547938234832866, Name='Ahmad'),
#  Row(Column1=92, Column2=31, Column3=0.7591052747752021, Name='Ahmad'),
#  Row(Column1=99, Column2=31, Column3=0.5938728563641669, Name='Ahmad'),
#  Row(Column1=22, Column2=24, Column3=0.3745858282320891, Name='Ahmad'),
#  Row(Column1=29, Column2=28, Column3=0.1843920241354714, Name='Heba'),
#  Row(Column1=86, Column2=34, Column3=0.2751919162135016, Name='Ahmad'),
#  Row(Column1=68, Column2=26, Column3=0.12480988833686235, Name='Salem'),
#  Row(Column1=2, Column2=27, Column3=0.046072924191868925, Name='Ahmad'),
#  Row(Column1=75, Column2=31, Column3=0.21445583461586504, Name='Ahmad'),
#  Row(Column1=98, Column2=34, Column3=0.17434979274976736, Name='Ahmad'),
#  Row(Column1=70, Column2=32, Column3=0.1980272478481776, Name='Ahmad'),
#  Row(Column1=88, Column2=28, Column3=0.5963704008218482, Name='Ahmad'),
#  Row(Column1=36, Column2=30, Column3=0.4640744337322771, Name='Heba'),
#  Row(Column1=6, Column2=31, Column3=0.5055719976692268, Name='Heba'),
#  Row(Column1=17, Column2=34, Column3=0.3351983120027817, Name='Ahmad'),
#  Row(Column1=5, Column2=32, Column3=0.6115405394396758, Name='Ahmad'),
#  Row(Column1=94, Column2=30, Column3=0.2296877808177148, Name='Salem'),
#  Row(Column1=4, Column2=32, Column3=0.828504571110953, Name='Ahmad'),
#  Row(Column1=84, Column2=29, Column3=0.1656642341916703, Name='Salem'),
#  Row(Column1=45, Column2=28, Column3=0.9110312011557795, Name='Ahmad'),
#  Row(Column1=32, Column2=30, Column3=0.48328807892970194, Name='Heba'),
#  Row(Column1=80, Column2=29, Column3=0.27285700527419854, Name='Ahmad'),
#  Row(Column1=42, Column2=25, Column3=0.8406939475890397, Name='Heba'),
#  Row(Column1=80, Column2=29, Column3=0.588945164880191, Name='Ahmad'),
#  Row(Column1=96, Column2=26, Column3=0.17353639114680286, Name='Ahmad'),
#  Row(Column1=89, Column2=30, Column3=0.4703927537919347, Name='Salem'),
#  Row(Column1=13, Column2=29, Column3=0.8764758291627629, Name='Heba'),
#  Row(Column1=65, Column2=25, Column3=0.6679134658718937, Name='Ahmad'),
#  Row(Column1=40, Column2=26, Column3=0.7946391193727994, Name='Ahmad'),
#  Row(Column1=54, Column2=28, Column3=0.7284785110990182, Name='Ahmad'),
#  Row(Column1=88, Column2=29, Column3=0.9641192214618955, Name='Ahmad'),
#  Row(Column1=21, Column2=25, Column3=0.6601599873807615, Name='Ahmad'),
#  Row(Column1=61, Column2=25, Column3=0.6513911413975979, Name='Noor'),
#  Row(Column1=78, Column2=32, Column3=0.7646058057971338, Name='Salem'),
#  Row(Column1=63, Column2=30, Column3=0.4850873393468035, Name='Heba'),
#  Row(Column1=59, Column2=33, Column3=0.07330829384903403, Name='Salem'),
#  Row(Column1=51, Column2=33, Column3=0.6424420963905355, Name='Heba'),
#  Row(Column1=28, Column2=30, Column3=0.6441620009988599, Name='Ahmad'),
#  Row(Column1=48, Column2=25, Column3=0.6580710859836771, Name='Salem'),
#  Row(Column1=32, Column2=33, Column3=0.4391366367887004, Name='Heba'),
#  Row(Column1=59, Column2=29, Column3=0.33914334879892327, Name='Heba'),
#  Row(Column1=4, Column2=30, Column3=0.9380507645582667, Name='Salem'),
#  Row(Column1=53, Column2=32, Column3=0.5936419163705989, Name='Ahmad'),
#  Row(Column1=25, Column2=28, Column3=0.37092346234718143, Name='Ahmad'),
#  Row(Column1=63, Column2=30, Column3=0.3954305840683995, Name='Salem'),
#  Row(Column1=26, Column2=26, Column3=0.6862543788309238, Name='Ahmad'),
#  Row(Column1=37, Column2=31, Column3=0.015058643299513008, Name='Salem'),
#  Row(Column1=56, Column2=24, Column3=0.6402570744150582, Name='Salem'),
#  Row(Column1=24, Column2=26, Column3=0.2998287479556717, Name='Heba'),
#  Row(Column1=32, Column2=33, Column3=0.5864387949770291, Name='Noor'),
#  Row(Column1=38, Column2=26, Column3=0.15988793409229118, Name='Ahmad'),
#  Row(Column1=31, Column2=31, Column3=0.21421704885183612, Name='Noor'),
#  Row(Column1=39, Column2=30, Column3=0.7481247954017538, Name='Ahmad'),
#  Row(Column1=8, Column2=30, Column3=0.6571666517040381, Name='Ahmad'),
#  Row(Column1=18, Column2=25, Column3=0.718177077978391, Name='Ahmad'),
#  Row(Column1=51, Column2=31, Column3=0.19255202256498216, Name='Ahmad'),
#  Row(Column1=38, Column2=33, Column3=0.16929989449945093, Name='Noor'),
#  Row(Column1=15, Column2=26, Column3=0.8984000634316085, Name='Heba'),
#  Row(Column1=39, Column2=28, Column3=0.7922477115376324, Name='Heba'),
#  Row(Column1=93, Column2=31, Column3=0.07986799486585427, Name='Noor'),
#  Row(Column1=26, Column2=24, Column3=0.95422132167708, Name='Ahmad'),
#  Row(Column1=71, Column2=34, Column3=0.4263669817703315, Name='Salem'),
#  Row(Column1=67, Column2=31, Column3=0.509199177180825, Name='Salem'),
#  Row(Column1=81, Column2=24, Column3=0.8093477037762814, Name='Ahmad'),
#  Row(Column1=15, Column2=30, Column3=0.7101210112977501, Name='Ahmad'),
#  Row(Column1=86, Column2=33, Column3=0.8565511917673283, Name='Salem'),
#  Row(Column1=76, Column2=25, Column3=0.6464813795486035, Name='Ahmad'),
#  Row(Column1=2, Column2=26, Column3=0.3435994091468412, Name='Salem'),
#  Row(Column1=59, Column2=33, Column3=0.9149064880721758, Name='Salem'),
#  Row(Column1=88, Column2=27, Column3=0.29655999605840455, Name='Noor'),
#  Row(Column1=65, Column2=31, Column3=0.5794109815504956, Name='Ahmad'),
#  Row(Column1=23, Column2=29, Column3=0.11546949309780652, Name='Heba'),
#  Row(Column1=74, Column2=30, Column3=0.3290729133449133, Name='Ahmad'),
#  Row(Column1=24, Column2=30, Column3=0.6045402509901047, Name='Ahmad'),
#  Row(Column1=71, Column2=30, Column3=0.2748688944209633, Name='Heba'),
#  Row(Column1=37, Column2=32, Column3=0.4034948169097028, Name='Ahmad'),
#  Row(Column1=15, Column2=28, Column3=0.16188437989513194, Name='Ahmad'),
#  Row(Column1=56, Column2=33, Column3=0.5561009966898837, Name='Ahmad'),
#  Row(Column1=19, Column2=31, Column3=0.9665441228902273, Name='Heba')]

# %% [markdown]
# ####show: Prints the first n rows to the console.

# %%
df.show(3,vertical=True)
# Out:
# -RECORD 0---------------------
#  Column1 | 59
#  Column2 | 31
#  Column3 | 0.3736162801327363
#  Name    | Heba
# -RECORD 1---------------------
#  Column1 | 75
#  Column2 | 28
#  Column3 | 0.6738893595145822
#  Name    | Ahmad
# -RECORD 2---------------------
#  Column1 | 60
#  Column2 | 32
#  Column3 | 0.8902618906934348
#  Name    | Ahmad
# only showing top 3 rows

# %% [markdown]
# ####take: Returns the first ``num`` rows as a :class:`list` of :class:`Row`.

# %%
df.take(10)
# Out:
# [Row(Column1=59, Column2=31, Column3=0.3736162801327363, Name='Heba'),
#  Row(Column1=75, Column2=28, Column3=0.6738893595145822, Name='Ahmad'),
#  Row(Column1=60, Column2=32, Column3=0.8902618906934348, Name='Ahmad'),
#  Row(Column1=59, Column2=27, Column3=0.46576177438844135, Name='Salem'),
#  Row(Column1=72, Column2=33, Column3=0.366988985365314, Name='Salem'),
#  Row(Column1=30, Column2=25, Column3=0.8782213069230462, Name='Heba'),
#  Row(Column1=31, Column2=31, Column3=0.569279252419162, Name='Heba'),
#  Row(Column1=80, Column2=27, Column3=0.6620355108525771, Name='Ahmad'),
#  Row(Column1=66, Column2=33, Column3=0.10639853662690446, Name='Ahmad'),
#  Row(Column1=32, Column2=33, Column3=0.4802386999319148, Name='Salem')]

# %%
df1 = spark.createDataFrame(df.take(10))
df1.show(20)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |     59|     31| 0.3736162801327363| Heba|
# |     75|     28| 0.6738893595145822|Ahmad|
# |     60|     32| 0.8902618906934348|Ahmad|
# |     59|     27|0.46576177438844135|Salem|
# |     72|     33|  0.366988985365314|Salem|
# |     30|     25| 0.8782213069230462| Heba|
# |     31|     31|  0.569279252419162| Heba|
# |     80|     27| 0.6620355108525771|Ahmad|
# |     66|     33|0.10639853662690446|Ahmad|
# |     32|     33| 0.4802386999319148|Salem|
# +-------+-------+-------------------+-----+

# %% [markdown]
# ####head: Returns the first ``n`` rows.

# %%
df.head(10)
# Out:
# [Row(Column1=59, Column2=31, Column3=0.3736162801327363, Name='Heba'),
#  Row(Column1=75, Column2=28, Column3=0.6738893595145822, Name='Ahmad'),
#  Row(Column1=60, Column2=32, Column3=0.8902618906934348, Name='Ahmad'),
#  Row(Column1=59, Column2=27, Column3=0.46576177438844135, Name='Salem'),
#  Row(Column1=72, Column2=33, Column3=0.366988985365314, Name='Salem'),
#  Row(Column1=30, Column2=25, Column3=0.8782213069230462, Name='Heba'),
#  Row(Column1=31, Column2=31, Column3=0.569279252419162, Name='Heba'),
#  Row(Column1=80, Column2=27, Column3=0.6620355108525771, Name='Ahmad'),
#  Row(Column1=66, Column2=33, Column3=0.10639853662690446, Name='Ahmad'),
#  Row(Column1=32, Column2=33, Column3=0.4802386999319148, Name='Salem')]

# %%
df2 = spark.createDataFrame(df.head(10))
df2.show(100)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |     59|     31| 0.3736162801327363| Heba|
# |     75|     28| 0.6738893595145822|Ahmad|
# |     60|     32| 0.8902618906934348|Ahmad|
# |     59|     27|0.46576177438844135|Salem|
# |     72|     33|  0.366988985365314|Salem|
# |     30|     25| 0.8782213069230462| Heba|
# |     31|     31|  0.569279252419162| Heba|
# |     80|     27| 0.6620355108525771|Ahmad|
# |     66|     33|0.10639853662690446|Ahmad|
# |     32|     33| 0.4802386999319148|Salem|
# +-------+-------+-------------------+-----+

# %% [markdown]
# ####count: Returns the number of rows in this :class:`DataFrame`.

# %%
df.count()
# Out:
# 1000

# %% [markdown]
# ####first: Returns the first row as a :class:`Row`.

# %%
df.first
# Out:
# <bound method DataFrame.first of DataFrame[Column1: bigint, Column2: bigint, Column3: double, Name: string]>

# %%
df.first()
# Out:
# Row(Column1=59, Column2=31, Column3=0.3736162801327363, Name='Heba')

# %% [markdown]
# ####toPandas: Returns the contents of this :class:`DataFrame` as Pandas ``pandas.DataFrame``.

# %%
DF=df.toPandas()

# %%
DF.head()
# Out:
#    Column1  Column2   Column3   Name
# 0       59       31  0.373616   Heba
# 1       75       28  0.673889  Ahmad
# 2       60       32  0.890262  Ahmad
# 3       59       27  0.465762  Salem
# 4       72       33  0.366989  Salem

# %%
DF.tail()
# Out:
#      Column1  Column2   Column3   Name
# 995       71       30  0.274869   Heba
# 996       37       32  0.403495  Ahmad
# 997       15       28  0.161884  Ahmad
# 998       56       33  0.556101  Ahmad
# 999       19       31  0.966544   Heba

# %%
DF.describe()
# Out:
#            Column1      Column2      Column3
# count  1000.000000  1000.000000  1000.000000
# mean     48.835000    28.926000     0.505739
# std      28.580038     3.116767     0.289358
# min       1.000000    24.000000     0.000775
# 25%      24.000000    26.000000     0.268140
# 50%      48.000000    29.000000     0.505729
# 75%      73.250000    32.000000     0.757970
# max      99.000000    34.000000     0.999327

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  1000 non-null   int64
#  1   Column2  1000 non-null   int64
#  2   Column3  1000 non-null   float64
#  3   Name     1000 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 31.4+ KB

# %%
DF['Column5']=DF['Column2'].apply(lambda x : (x/10)-2)
DF.head(3)
# Out:
#    Column1  Column2   Column3   Name  Column5
# 0       59       31  0.373616   Heba      1.1
# 1       75       28  0.673889  Ahmad      0.8
# 2       60       32  0.890262  Ahmad      1.2

# %%
def transFunc(x):
  y=x**2/10
  return y 

DF['Column6']=DF['Column2'].apply(transFunc)
DF.head(3)
# Out:
#    Column1  Column2   Column3   Name  Column5  Column6
# 0       59       31  0.373616   Heba      1.1     96.1
# 1       75       28  0.673889  Ahmad      0.8     78.4
# 2       60       32  0.890262  Ahmad      1.2    102.4

# %%
import matplotlib.pyplot as plt 

ax = DF[DF.Name=='Heba']['Column1'].plot.hist(bins=10, alpha=0.5)
ax = DF[DF.Name=='Salem']['Column1'].plot.hist(bins=10, alpha=0.5)
plt.legend(['Heba','Salem'])

# %% [markdown]
# ####write: Returns the contents of this :class:`DataFrame` as Pandas ``pandas.DataFrame``.

# %%
df.write?

# %%
df.write.save?

# %%
df.write.save(path='MyProcessed', format='csv')

# %%
# !ls -lh MyProcessed
# Out:
# total 32K
# -rw-r--r-- 1 root root 16K Dec  1 16:06 part-00000-a54eee8f-3b13-4f3a-8be6-79d3fd0edf37-c000.csv
# -rw-r--r-- 1 root root 16K Dec  1 16:06 part-00001-a54eee8f-3b13-4f3a-8be6-79d3fd0edf37-c000.csv
# -rw-r--r-- 1 root root   0 Dec  1 16:06 _SUCCESS

# %%
# !head -n 10 MyProcessed/content/MyProcessed/part-00000-a54eee8f-3b13-4f3a-8be6-79d3fd0edf37-c000.csv
# Out:
# head: cannot open 'MyProcessed/content/MyProcessed/part-00000-a54eee8f-3b13-4f3a-8be6-79d3fd0edf37-c000.csv' for reading: No such file or directory

# %%
# !head -n 10 MyProcessed/part-00001-39599817-195f-483d-9239-a3d241332dca-c000.csv

# %% [markdown]
# One important parameter is the number of partitions to cut the dataset into. Typically you want 2-4 partitions for each CPU in your cluster. Normally, Spark tries to set the number of partitions automatically based on your cluster. However, you can also set it manually. Lets do that

# %%
df.rdd.getNumPartitions()
# Out:
# 2

# %%
df.coalesce?

# %%
df.write.mode?

# %%
df2 = df.coalesce(1)

# %%
df2.rdd.getNumPartitions()
# Out:
# 1

# %%
df.write.mode("overwrite").csv("MyProcessed", header=True)

# %%
# !ls MyProcessed
# Out:
# part-00000-3f0efac1-e35e-45e6-b6cf-4bf85a073e70-c000.csv  _SUCCESS
# part-00001-3f0efac1-e35e-45e6-b6cf-4bf85a073e70-c000.csv

# %%
df2.write.mode("overwrite").csv("MyProcessed", header=True)

# %%
# !ls MyProcessed
# Out:
# part-00000-c0ea6db1-ab2d-4d20-8bc0-43c5d1bc45e3-c000.csv  _SUCCESS

# %% [markdown]
# ##Properties

# %% [markdown]
# ####columns: Returns the number of rows in this DataFrame

# %%
df.columns?

# %%
df.columns
# Out:
# ['Column1', 'Column2', 'Column3', 'Name']

# %% [markdown]
# ####dtypes: eturns all column names and their data types as a list.
#
# ---

# %%
df.dtypes?

# %%
df.dtypes
# Out:
# [('Column1', 'bigint'),
#  ('Column2', 'bigint'),
#  ('Column3', 'double'),
#  ('Name', 'string')]

# %% [markdown]
# ####isLocal:  Returns ``True`` if the :func:`collect` and :func:`take` methods can be run locally without any Spark executors.
#
# ---

# %%
df.isLocal?

# %%
df.isLocal()
# Out:
# False

# %% [markdown]
# ####*isStreaming*: Returns true if this :class:Dataset contains one or more sources that continuouslyreturn data as it arrives.
# ---

# %%
df.isStreaming?

# %%
df.isStreaming
# Out:
# False

# %% [markdown]
# ####*na*: Returns a :class:DataFrameNaFunctions for handling missing values.
# ---

# %%
df.na?

# %%
df.na.drop?

# %%
df.na.fill?

# %%
df.na.replace?

# %%
df.na.drop().count()
# Out:
# 1000

# %%
df2 = spark.createDataFrame([{"Column1": np.nan, 
                             "Column2":np.random.randint(24,35), 
                             "Column3":np.random.random(),
                             "Name":str(np.random.choice(NameList,p=[.5,.2,.1,.2])),
                             }
                              for i in range(NumberOfSamples)])
# Out:
# /content/spark-2.4.7-bin-hadoop2.7/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
df2.show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |    NaN|     24|0.43463458527774934| Noor|
# |    NaN|     33|0.19127507847178815|Ahmad|
# |    NaN|     34| 0.4761364495607032| Noor|
# |    NaN|     25|0.25451227236901797|Ahmad|
# |    NaN|     34| 0.1754860806431765| Heba|
# |    NaN|     28|0.03699975112887943|Ahmad|
# |    NaN|     34|0.16668556332117335|Ahmad|
# |    NaN|     26|0.12620499841216082|Salem|
# |    NaN|     24| 0.1749059663922925|Ahmad|
# |    NaN|     30| 0.8383892598736717|Ahmad|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %%
df2.na.drop().count()
# Out:
# 0

# %%
df2.na.fill(1).show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |    1.0|     24|0.43463458527774934| Noor|
# |    1.0|     33|0.19127507847178815|Ahmad|
# |    1.0|     34| 0.4761364495607032| Noor|
# |    1.0|     25|0.25451227236901797|Ahmad|
# |    1.0|     34| 0.1754860806431765| Heba|
# |    1.0|     28|0.03699975112887943|Ahmad|
# |    1.0|     34|0.16668556332117335|Ahmad|
# |    1.0|     26|0.12620499841216082|Salem|
# |    1.0|     24| 0.1749059663922925|Ahmad|
# |    1.0|     30| 0.8383892598736717|Ahmad|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %%
df2.show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |    NaN|     24|0.43463458527774934| Noor|
# |    NaN|     33|0.19127507847178815|Ahmad|
# |    NaN|     34| 0.4761364495607032| Noor|
# |    NaN|     25|0.25451227236901797|Ahmad|
# |    NaN|     34| 0.1754860806431765| Heba|
# |    NaN|     28|0.03699975112887943|Ahmad|
# |    NaN|     34|0.16668556332117335|Ahmad|
# |    NaN|     26|0.12620499841216082|Salem|
# |    NaN|     24| 0.1749059663922925|Ahmad|
# |    NaN|     30| 0.8383892598736717|Ahmad|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %%
df2=df2.na.fill(10)
df2.show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |   10.0|     24|0.43463458527774934| Noor|
# |   10.0|     33|0.19127507847178815|Ahmad|
# |   10.0|     34| 0.4761364495607032| Noor|
# |   10.0|     25|0.25451227236901797|Ahmad|
# |   10.0|     34| 0.1754860806431765| Heba|
# |   10.0|     28|0.03699975112887943|Ahmad|
# |   10.0|     34|0.16668556332117335|Ahmad|
# |   10.0|     26|0.12620499841216082|Salem|
# |   10.0|     24| 0.1749059663922925|Ahmad|
# |   10.0|     30| 0.8383892598736717|Ahmad|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ####*describe*: Computes basic statistics for numeric and string columns.
# ---

# %%
df.describe?

# %%
df.describe().show()
# Out:
# +-------+------------------+-----------------+--------------------+-----+
# |summary|           Column1|          Column2|             Column3| Name|
# +-------+------------------+-----------------+--------------------+-----+
# |  count|              1000|             1000|                1000| 1000|
# |   mean|            48.835|           28.926|  0.5057385013902848| null|
# | stddev|28.580038376349215|3.116767273672874|  0.2893575566944415| null|
# |    min|                 1|               24|7.751747625006633E-4|Ahmad|
# |    max|                99|               34|  0.9993267042904767|Salem|
# +-------+------------------+-----------------+--------------------+-----+

# %%
df.describe(['Column1']).show()
# Out:
# +-------+------------------+
# |summary|           Column1|
# +-------+------------------+
# |  count|              1000|
# |   mean|            48.835|
# | stddev|28.580038376349215|
# |    min|                 1|
# |    max|                99|
# +-------+------------------+

# %% [markdown]
# ####*distinct*: Returns a new :class:DataFrame containing the distinct rows in this :class:DataFrame.
# ---

# %%
df.distinct?

# %%
df.distinct().show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |     28|     31| 0.9601470574728143|Ahmad|
# |     52|     24| 0.7958291065009987| Heba|
# |     96|     29| 0.7401181702238403| Heba|
# |     84|     29|0.27564281723938844|Ahmad|
# |     20|     24|0.34207026999123114|Ahmad|
# |      4|     25| 0.9581453499770243| Noor|
# |     19|     32| 0.5838059952613988| Heba|
# |     63|     25|0.47433202803592434|Ahmad|
# |     49|     29|  0.281772949522476|Ahmad|
# |     88|     34| 0.7908333579040555|Salem|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %%
df.distinct().count()
# Out:
# 1000

# %%
df.select('Name').distinct().show()
# Out:
# +-----+
# | Name|
# +-----+
# |Ahmad|
# |Salem|
# | Heba|
# | Noor|
# +-----+

# %%
df.select('Name').distinct().count()
# Out:
# 4

# %% [markdown]
# ####*drop*: Returns a new :class:DataFrame that drops the specified column. This is a no-op if schema doesn't contain the given column name(s).
# ---

# %%
df.drop?

# %%
df.columns
# Out:
# ['Column1', 'Column2', 'Column3', 'Name']

# %%
df.drop('Column1').show(3)
# Out:
# +-------+------------------+-----+
# |Column2|           Column3| Name|
# +-------+------------------+-----+
# |     31|0.3736162801327363| Heba|
# |     28|0.6738893595145822|Ahmad|
# |     32|0.8902618906934348|Ahmad|
# +-------+------------------+-----+
# only showing top 3 rows

# %%
df.show(3)
# Out:
# +-------+-------+------------------+-----+
# |Column1|Column2|           Column3| Name|
# +-------+-------+------------------+-----+
# |     59|     31|0.3736162801327363| Heba|
# |     75|     28|0.6738893595145822|Ahmad|
# |     60|     32|0.8902618906934348|Ahmad|
# +-------+-------+------------------+-----+
# only showing top 3 rows

# %%
df1=df.drop('Column1')
df1.show(3)
# Out:
# +-------+------------------+-----+
# |Column2|           Column3| Name|
# +-------+------------------+-----+
# |     31|0.3736162801327363| Heba|
# |     28|0.6738893595145822|Ahmad|
# |     32|0.8902618906934348|Ahmad|
# +-------+------------------+-----+
# only showing top 3 rows

# %% [markdown]
# ####*drop_duplicates* drop_duplicates is an alias for :func:dropDuplicates.
# ---

# %% [markdown]
# ####*dropDuplicates*: Returns a new :class:DataFrame that drops the specified column. This is a no-op if schema doesn't contain the given column name(s).
# ---

# %%
df.dropDuplicates?

# %%
from pyspark.sql import Row
sparkContext=spark.sparkContext

df3 = sparkContext.parallelize([ 
                                Row(name='Alice', age=5, height=80), 
                                Row(name='Alice', age=5, height=80), 
                                Row(name='Alice', age=10, height=80)]).toDF()
df3.dropDuplicates().show(3)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  5|    80|Alice|
# | 10|    80|Alice|
# +---+------+-----+

# %%
df3.dropDuplicates().count()
# Out:
# 2

# %%
df.dropDuplicates().count()
# Out:
# 1000

# %%
df.select("name").dropDuplicates().count()
# Out:
# 4

# %% [markdown]
# ####*dropna*: Returns a new :class:DataFrame that drops the specified column. This is a no-op if schema doesn't contain the given column name(s).
# ---

# %%
df.dropna?

# %%
from pyspark.sql import Row
sparkContext=spark.sparkContext

df4 = sparkContext.parallelize([ 
                                Row(name='Alice', age=9, height=80), 
                                Row(name='Frank', age=5, height=80), 
                                Row(name='Ahmad', age=10, height=np.nan)]).toDF()
df4.show(3)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# | 10|  null|Ahmad|
# +---+------+-----+

# %%
df4.dropna().show()
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# +---+------+-----+

# %% [markdown]
# ####*fillna*: Replace null values, alias for na.fill()
# ---

# %%
df4.show(3)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# | 10|  null|Ahmad|
# +---+------+-----+

# %%
df4.fillna(3).show()
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# | 10|     3|Ahmad|
# +---+------+-----+

# %%
fill_avg=df4.select('height').toPandas().mean()[0]
df4.fillna(fill_avg).show()
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# | 10|    80|Ahmad|
# +---+------+-----+

# %% [markdown]
# ####*filter*: Filters rows using the given condition.
# ---

# %%
df4.filter?

# %%
df4.show(10)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# |  5|    80|Frank|
# | 10|  null|Ahmad|
# +---+------+-----+

# %%
df4.filter(df4.age>5).show(3)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# | 10|  null|Ahmad|
# +---+------+-----+

# %%
df4.filter((df4.age>5)&(df4.name=='Alice')).show(3)
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# +---+------+-----+

# %%
Cond=(df4.age>5)&(df4.name=='Alice')

# %%
Cond
# Out:
# Column<b'((age > 5) AND (name = Alice))'>

# %%
df5=df4.filter(Cond)
df5.show()
# Out:
# +---+------+-----+
# |age|height| name|
# +---+------+-----+
# |  9|    80|Alice|
# +---+------+-----+

# %% [markdown]
# ####*withColumn*: Returns a new :class:DataFrame by adding a column or replacing theexisting column that has the same name.
# ---

# %%
df4.withColumn?

# %%
df4 = df4.withColumn('age2', df4.age + 2)

# %%
df4.show(3)
# Out:
# +---+------+-----+----+
# |age|height| name|age2|
# +---+------+-----+----+
# |  9|    80|Alice|  11|
# |  5|    80|Frank|   7|
# | 10|  null|Ahmad|  12|
# +---+------+-----+----+

# %%
from pyspark.sql import functions as F

# Create a column by adding 2 columns together
df4 = df4.withColumn("age3",F.col('age')+ F.col('age2'))

# Create a column 'ratio' by dividing one by another one
df4 = df4.withColumn("age4",F.col('age')*100/ F.col('age3'))

df4.show()
# Out:
# +---+------+-----+----+----+------------------+
# |age|height| name|age2|age3|              age4|
# +---+------+-----+----+----+------------------+
# |  9|    80|Alice|  11|  20|              45.0|
# |  5|    80|Frank|   7|  12|41.666666666666664|
# | 10|  null|Ahmad|  12|  22| 45.45454545454545|
# +---+------+-----+----+----+------------------+

# %% [markdown]
# ####*withColumnRenamed*: Returns a new :class:DataFrame by renaming an existing column. This is a no-op if schema doesn't contain the given column name.
# ---

# %%
df4.withColumnRenamed?

# %%
df4.withColumnRenamed('age','Orignal_age').show()
# Out:
# +-----------+------+-----+----+----+------------------+
# |Orignal_age|height| name|age2|age3|              age4|
# +-----------+------+-----+----+----+------------------+
# |          9|    80|Alice|  11|  20|              45.0|
# |          5|    80|Frank|   7|  12|41.666666666666664|
# |         10|  null|Ahmad|  12|  22| 45.45454545454545|
# +-----------+------+-----+----+----+------------------+

# %% [markdown]
# ####*groupBy*: Groups the :class:DataFrame using the specified columns, so we can run aggregation on them.
# ---

# %%
df4.groupBy?

# %%
df.show(10)
# Out:
# +-------+-------+-------------------+-----+
# |Column1|Column2|            Column3| Name|
# +-------+-------+-------------------+-----+
# |     59|     31| 0.3736162801327363| Heba|
# |     75|     28| 0.6738893595145822|Ahmad|
# |     60|     32| 0.8902618906934348|Ahmad|
# |     59|     27|0.46576177438844135|Salem|
# |     72|     33|  0.366988985365314|Salem|
# |     30|     25| 0.8782213069230462| Heba|
# |     31|     31|  0.569279252419162| Heba|
# |     80|     27| 0.6620355108525771|Ahmad|
# |     66|     33|0.10639853662690446|Ahmad|
# |     32|     33| 0.4802386999319148|Salem|
# +-------+-------+-------------------+-----+
# only showing top 10 rows

# %%
df.groupBy('Name').avg().show()
# Out:
# +-----+------------------+------------------+-------------------+
# | Name|      avg(Column1)|      avg(Column2)|       avg(Column3)|
# +-----+------------------+------------------+-------------------+
# |Ahmad|48.509164969450104|29.069246435845216| 0.5134887004971336|
# |Salem| 49.39010989010989|28.945054945054945| 0.5091430853692043|
# | Heba|49.207207207207205| 28.66216216216216| 0.4904096851223553|
# | Noor| 48.60952380952381| 28.78095238095238|0.49600531249365637|
# +-----+------------------+------------------+-------------------+

# %%
df.groupBy('Name').max().show()
# Out:
# +-----+------------+------------+------------------+
# | Name|max(Column1)|max(Column2)|      max(Column3)|
# +-----+------------+------------+------------------+
# |Ahmad|          99|          34|0.9991036296931801|
# |Salem|          99|          34|0.9993267042904767|
# | Heba|          98|          34|0.9992195440304341|
# | Noor|          99|          34|0.9914587214325291|
# +-----+------------+------------+------------------+

# %%
df.groupBy('Name').count().show()
# Out:
# +-----+-----+
# | Name|count|
# +-----+-----+
# |Ahmad|  491|
# |Salem|  182|
# | Heba|  222|
# | Noor|  105|
# +-----+-----+

# %%
df.groupBy('Name').count().collect()
# Out:
# [Row(Name='Ahmad', count=491),
#  Row(Name='Salem', count=182),
#  Row(Name='Heba', count=222),
#  Row(Name='Noor', count=105)]

# %%
df.groupBy('Name').count().toPandas()
# Out:
#     Name  count
# 0  Ahmad    491
# 1  Salem    182
# 2   Heba    222
# 3   Noor    105

# %%
sorted(df.groupBy('Name').agg({'Column1': 'mean'}).collect())
# Out:
# [Row(Name='Ahmad', avg(Column1)=48.509164969450104),
#  Row(Name='Heba', avg(Column1)=49.207207207207205),
#  Row(Name='Noor', avg(Column1)=48.60952380952381),
#  Row(Name='Salem', avg(Column1)=49.39010989010989)]

# %%
df.groupBy('Name').agg({'Column1': 'mean'}).toPandas()
# Out:
#     Name  avg(Column1)
# 0  Ahmad     48.509165
# 1  Salem     49.390110
# 2   Heba     49.207207
# 3   Noor     48.609524

# %%
df.groupBy('Name').agg({'Column1': 'count'}).toPandas()
# Out:
#     Name  count(Column1)
# 0  Ahmad             491
# 1  Salem             182
# 2   Heba             222
# 3   Noor             105

# %%
df.limit(100).groupBy('Name').agg({'Column1': 'count'}).toPandas()
# Out:
#     Name  count(Column1)
# 0   Heba              22
# 1  Ahmad              53
# 2  Salem              14
# 3   Noor              11

# %% [markdown]
# ####*limit*: Limits the result count to the number specified.
# ---

# %%
df.limit?

# %%
df.limit(100).count()
# Out:
# 100

# %%
#df.limit(100).select(['Name','Column1']).collect()
DF_100=df.limit(100).select(['Name','Column1']).toPandas()
DF_100.head(10)
# Out:
#     Name  Column1
# 0   Heba       59
# 1  Ahmad       75
# 2  Ahmad       60
# 3  Salem       59
# 4  Salem       72
# 5   Heba       30
# 6   Heba       31
# 7  Ahmad       80
# 8  Ahmad       66
# 9  Salem       32

# %%
len(DF_100)
# Out:
# 100

# %% [markdown]
# ####*sample*: Returns a sampled subset of this :class:DataFrame.
# ---

# %%
df.sample?

# %%
df = spark.range(100)

df.sample(fraction=0.5, seed=3).count()
# Out:
# 49

# %%
df.sample(fraction=0.5, seed=3).show(10)
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  2|
# |  5|
# |  8|
# | 10|
# | 11|
# | 12|
# | 14|
# | 15|
# | 16|
# +---+
# only showing top 10 rows

# %%
 df.sample(withReplacement=True, fraction=0.5, seed=3).show(10)
# Out:
# +---+
# | id|
# +---+
# |  5|
# |  6|
# | 10|
# | 13|
# | 21|
# | 27|
# | 27|
# | 27|
# | 28|
# | 31|
# +---+
# only showing top 10 rows

# %%
NumberOfSamples=int(10000)

df = spark.createDataFrame([{"Column1": np.random.randint(1,100), 
                             "Column2":np.random.randint(24,35), 
                             "Column3":np.random.random(),
                             "Name":str(np.random.choice(NameList,p=[.5,.2,.1,.2])),
                             }
                              for i in range(NumberOfSamples)])
# Out:
# /content/spark-2.4.7-bin-hadoop2.7/python/pyspark/sql/session.py:346: UserWarning: inferring schema from dict is deprecated,please use pyspark.sql.Row instead
#   warnings.warn("inferring schema from dict is deprecated,"

# %%
df.count()
# Out:
# 10000

# %%
df_sample=df.sample(withReplacement=False, fraction=0.5, seed=3)
df_sample.count()
# Out:
# 4985

# %% [markdown]
# ####*select*:Projects a set of expressions and returns a new :class:`DataFrame`
# ---

# %%
df.select('*').show(10)
# Out:
# +-------+-------+--------------------+-----+
# |Column1|Column2|             Column3| Name|
# +-------+-------+--------------------+-----+
# |     77|     32|  0.9639776748618206| Noor|
# |     31|     32|   0.779031406308421|Ahmad|
# |     75|     24|  0.5146530811196018|Ahmad|
# |     62|     33|  0.9639608380004595|Ahmad|
# |     66|     25|  0.4798610873986202|Ahmad|
# |     54|     29| 0.39399437545362026|Ahmad|
# |     34|     24|  0.4252072118728347|Ahmad|
# |     68|     24|0.012684810920411627|Salem|
# |     76|     30| 0.26633328647166365|Ahmad|
# |     22|     34|  0.7573962980100326|Ahmad|
# +-------+-------+--------------------+-----+
# only showing top 10 rows

# %%
df.select?

# %%
df.select('Name','Column2').filter(df.Column2>30).show(10)
# Out:
# +-----+-------+
# | Name|Column2|
# +-----+-------+
# | Noor|     32|
# |Ahmad|     32|
# |Ahmad|     33|
# |Ahmad|     34|
# |Ahmad|     34|
# | Heba|     34|
# |Ahmad|     33|
# |Ahmad|     32|
# |Ahmad|     32|
# | Heba|     33|
# +-----+-------+
# only showing top 10 rows

# %%
df.select('Name','Column2').filter(df.Column2>30).filter(df.Name=='Ahmad').show(10)
# Out:
# +-----+-------+
# | Name|Column2|
# +-----+-------+
# |Ahmad|     32|
# |Ahmad|     33|
# |Ahmad|     34|
# |Ahmad|     34|
# |Ahmad|     33|
# |Ahmad|     32|
# |Ahmad|     32|
# |Ahmad|     32|
# |Ahmad|     34|
# |Ahmad|     32|
# +-----+-------+
# only showing top 10 rows

# %%
DF_2=df.select('Name','Column2').filter(df.Column2>30).filter(df.Name=='Ahmad').toPandas()

# %%
DF_2.describe()
# Out:
#            Column2
# count  1843.000000
# mean     32.451438
# std       1.108256
# min      31.000000
# 25%      31.000000
# 50%      32.000000
# 75%      33.000000
# max      34.000000

# %%
DF_2=df.sample(0.1).select('Name','Column2').filter(df.Column2>30).filter(df.Name=='Ahmad').toPandas()
DF_2.describe()
# Out:
#           Column2
# count  185.000000
# mean    32.508108
# std      1.142646
# min     31.000000
# 25%     32.000000
# 50%     32.000000
# 75%     34.000000
# max     34.000000

# %%
df.sample(.1).select('Name','Column2').filter(df.Column2>30).filter(df.Name=='Ahmad').summary().show()
# Out:
# +-------+-----+-----------------+
# |summary| Name|          Column2|
# +-------+-----+-----------------+
# |  count|  193|              193|
# |   mean| null|32.53367875647668|
# | stddev| null|1.065635295851782|
# |    min|Ahmad|               31|
# |    25%| null|               32|
# |    50%| null|               33|
# |    75%| null|               33|
# |    max|Ahmad|               34|
# +-------+-----+-----------------+

# %%
df.sample(.1).select('Name','Column2').filter(df.Column2>30).filter(df.Name=='Ahmad').summary().show()
# Out:
# +-------+-----+------------------+
# |summary| Name|           Column2|
# +-------+-----+------------------+
# |  count|  196|               196|
# |   mean| null|32.326530612244895|
# | stddev| null|1.1073230386290167|
# |    min|Ahmad|                31|
# |    25%| null|                31|
# |    50%| null|                32|
# |    75%| null|                33|
# |    max|Ahmad|                34|
# +-------+-----+------------------+

# %%
###Next
